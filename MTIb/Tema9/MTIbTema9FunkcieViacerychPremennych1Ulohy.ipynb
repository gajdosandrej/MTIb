# %% [markdown]
# **Autor:** Andrej Gajdoš  <br>
# *[Ústav matematických vied](https://www.upjs.sk/prirodovedecka-fakulta/ustav/umv/), [Prírodovedecká fakulta](https://www.upjs.sk/prirodovedecka-fakulta/), Univerzita Pavla Jozefa Šafárika v Košiciach,* <br>
# email: [andrej.gajdos@upjs.sk](mailto:andrej.gajdos@upjs.sk)
# ***
# **_Tento materiál vznikol za podpory grantu VVGS-2021-1758._**
# ***
#
# **<font size=6 color=green> MTIb: Téma 9 - Funkcie viacerých premenných I.: úlohy </font>**

# %% [markdown]
# ---
#
# **1. Sú dané dva body: $P=[1,2,1]$, $Q=[2,0,0]$. Ktorý z nich je bližšie k počiatku súradnicovej sústavy?**

# %% [markdown]
# ---
#
# **2. Napíšte a znázornite rovnicu gule s polomerom $r=2$ a so stredom v bode $S=[1,0,0]$.**

# %% [markdown]
# ---
#
# **3. Znázornite nasledujúce rovnice (sústavy rovníc) v trojrozmernom priestore:**
#
# $$\text{a) }z=4; \qquad \text{b) }x=-3; \qquad \text{c) }y=1; \qquad \text{d) }z=2, y=4.$$

# %% [markdown]
# ---
#
# **4. Nájdite predpis lineárnej funkcie, ktorej graf je rovina prechádzajúca bodmi $[0,0,0]$, $[0,2,-1]$, $[-3,0,-4]$.**

# %% [markdown]
# ---
#
# **5. Je daná tabuľka kalórií, ktoré sú spálené za minútu počas korčuľovania na kolieskových korčuliach a tieto kalórie závisia od váhy (v librách) a rýchlosti osoby (v míľach za hodinu).**
#
# ![tabulka_kalorie.PNG](attachment:tabulka_kalorie.PNG)
#
# **a) Vyzerajú údaje v tabuľke približne lineárne?**
#
# **b) Uveďte vzorec pre počet spálených kalórií za minútu $B$ v závislosti od hmotnosti $w$ a rýchlosti $s$. Má vzorec zmysel pre všetky hmotnosti a rýchlosti?**
#
# **c) Kto spaľuje viac celkových kalórií na trati dlhej $10$ míľ: Osoba s hmotnosťou $120$ lb idúca $10$ míľ / h alebo osoba s hmotnosťou $180$ lb idúca 8 míľ / h? Ktorý z týchto dvoch ľudí spáli viac kalórií na jednu libru svojej váhy pri ceste dlhej $10$  míľ?**
#
# **d) Pomocou úlohy a) nájdite vzorec pre počet spálených kalórií $P$ na libru hmotnosti, v závisosti od $w$ a $s$, pre osobu vážiacu $w$ libier, ktorá prejde na kolieskových korčuliach dráhu $10$ míľ rýchlosťou $s$ mph.**

# %% [markdown]
# ---
#
# **6. Nájdite predpisy lineárnych funkcií dvoch premenných, ktoré by odpovedali nasledujúcim vrstevnicovým diagramom:**
#
# ![linearna_funkcia_vrstevnice_uloha.PNG](attachment:linearna_funkcia_vrstevnice_uloha.PNG)

# %% [markdown]
# ---
#
# **7. Nájdite predpis funkcie $f(x,y)$, ktorá je rastúca vzhľadom na premennú $x$ a klesajúca vzhľadom na premennú $y$.**

# %% [markdown]
# ---
#
# **8. S využitím Sage určte a v rovine $xy$ vykreslite definičné obory nasledujúcich funkcií:**
#
# $$\text{a) }z=\ln\left(1-\left(x^2+y^2\right)\right); \qquad \text{b) }z=\sqrt{\frac{x-x^2-y^2}{x^2-y}}; \qquad \text{c) }z=\frac{\sqrt{x^2-y}+\sqrt{x-y^2}}{x}; \qquad \text{d) }z=\ln\left[x\ln\left(y-x\right)\right]+e^{2x-1};$$
#
# $$\text{e) }z=\sqrt{36-4x^2-9y^2}; \qquad \text{f) }z=\frac{\sqrt{y-2x^2}}{\ln\left(1-x^2-y^2\right)}; \qquad \text{g) }z=\sqrt{\frac{x^2+y^2-x}{2x-x^2-y^2}}; \qquad \text{h) }z=\mathrm{arcsin}\frac{x+y}{x}.$$

# %% [markdown]
# ---
#
# **9. S využitím Sage určte definičné obory nasledujúcich funkcií:**
#
# $$\text{a) }f(x,y)=\frac{1}{x}+\frac{1}{y-1}; \qquad \text{b) }f(x,y)=\frac{1}{25-y^2-x^2}; \qquad \text{c) }f(x,y)=\frac{x^2y}{2x+|y|}; \qquad \text{d) }f(x,y)=\frac{2}{\sqrt{xy}};$$
#
# $$\text{e) }f(x,y,z)=\ln(xyz); \qquad \text{f) }f(x,y,z)=\sqrt{4-x^2-y^2-z^2}; \qquad \text{g) }f(x,y)=\ln(x\sin y); \qquad \text{h) }f(x,y)=\arcsin\frac{x}{x+y}+\sqrt{2y-x^2-y^2}.$$

# %% [markdown]
# ---
#
# **10. Pomocou Sage vykreslite v 3D tieto plochy:**
#
# $$\text{a) }z=\frac{1}{x^2+y^2}; \qquad \text{b) }z=-e^{-x^2-y^2}; \qquad \text{c) }z=x+2y+3; \qquad \text{d) }z=-y^2;$$
#
# $$\text{e) }z=x^3-\sin y; \qquad \text{f) }z=3; \qquad \text{g) }x^2+y^2+z^2=9; \qquad \text{h) }z=x^2+y^2+4;$$
#
# $$\text{i) }z=5-x^2-y^2; \qquad \text{j) }z=y^2; \qquad \text{k) }2x+4y+3z=12; \qquad \text{l) }x^2+y^2=4;$$
#
# $$\text{m) }x^2+z^2=4; \qquad \text{n) }z=xye^{-(x^2+y^2)}; \qquad \text{o) }z=\cos\left(\sqrt{x^2+y^2}\right); \qquad \text{p) }z=\sin y.$$
#
# $$\text{q) }z=-\frac{1}{x^2+y^2}; \qquad \text{r) }\cos^2x\cos^2y; \qquad \text{s) }z=\frac{\sin\left(x^2+y^2\right)}{x^2+y^2}; \qquad \text{t) }z=\cos(xy);$$
#
# $$\text{u) }z=|x||y|; \qquad \text{v) }z=\left(2x^2+y^2\right)e^{1-x^2-y^2}.$$

# %% [markdown]
# ---
#
# **11. Pre nasledujúce funkcie vykreslite v Sage vrstevnicové diagramy:**
#
# $$\text{a) }f(x,y)=x+y; \qquad \text{b) }f(x,y)=3x+3y; \qquad \text{c) }f(x,y)=x^2+y^2; \qquad \text{d) }f(x,y)=-x^2-y^2+1; \qquad \text{e) }f(x,y)=xy;$$
#
# $$\text{f) }f(x,y)=y-x^2; \qquad \text{g) }f(x,y)=x^2+2y^2; \qquad \text{h) }f(x,y)=\sqrt{x^2+2y^2}; \qquad \text{i) }f(x,y)=\cos\sqrt{x^2+y^2}.$$

# %% [markdown]
# ---
#
# **12. Nájdite príklad funkcie $f(x,y)$, ktorej graf pretína rovinu $xy$ v kruhu. Inými slovami, prienik roviny $xy$ s grafom hľadanej funkcie je kruh.**

# %% [markdown]
# ---
#
# **13. Pomocou zoznamu plôch v učebnom texte správne identifikujte plochy zadané rovnicami:.**
#
# $$\text{a) }x^2+y^2-z=0; \qquad \text{b) }-x^2-y^2+z^2=1; \qquad \text{c) }x+y=1; \qquad \text{d) }x^2+y^2/4+z^2=1.$$

# %% [markdown]
# ---
#
# **14. Rozhodnite, či nasledujúce úrovňové plochy môžu reprezentovať graf funkcie dvoch premenných $f(x,y)$. Ak áno, tak nájdite predpis takej funkcie (ako kontrolu môžete vykresliť grafy resp. plochy v Sage):**
#
# $$\text{a) }z-x^2-3y^2=0; \qquad \text{b) }2x+3y-5z-10=0; \qquad \text{c) }x^2+y^2+z^2-1=0; \qquad \text{d) }z^2=x^2+3y^2.$$

# %% [markdown]
# ---
#
# **15. Zostatok $B$ v dolároch na bankovom účte závisí od vloženej sumy $A$ dolárov, ročnej úrokovej sadzby $r$ % a času $t$ v mesiacoch od vkladu, teda $B = f (A, r, t)$.**
#
# **a) Je $f$ rastúcou funkciou v závislosti od $A$? Od $r$? Od $t$?**
#
# **b) Interpretujte vzťah $f(1250,1,25)\approx1276$ v správnych jednotkách.**

# %% [markdown]
# **Autor:** Andrej Gajdoš  <br>
# *[Ústav matematických vied](https://www.upjs.sk/prirodovedecka-fakulta/ustav/umv/), [Prírodovedecká fakulta](https://www.upjs.sk/prirodovedecka-fakulta/), Univerzita Pavla Jozefa Šafárika v Košiciach,* <br>
# email: [andrej.gajdos@upjs.sk](mailto:andrej.gajdos@upjs.sk)
# ***
# **_Tento materiál vznikol za podpory grantu VVGS-2021-1758._**
# ***
#
# **<font size=6 color=green> MTIb: Téma 9 - Funkcie viacerých premenných I.: úlohy k učebnému textu </font>**

# %% [markdown]
# ---
#
# **1. Vymyslite reálny (zo života) príklad funkcie viacerých premenných a poriadne ho vysvetlite.**

# %% [markdown]
# ---
#
# **2. Skúste v Príklade 6 vziať za $r$ $5$ rôznych kladných a $5$ rôznych záporných čísel a dosadiť ich do funkcie $f$ v tvare $f(0,-r)$. Na výpočet týchto funkčných hodnôt môžete využiť Sage.**

# %% [markdown]
# ---
#
# **3. Doplňte chýbajúce funkčné hodnoty v tabuľke pre funkciu z Príkladu 9.**
#
# ![tabulka_funkcne_hodnoty.PNG](attachment:tabulka_funkcne_hodnoty.PNG)

# %% [markdown]
# ---
#
# **4. Z galérie grafov (pred Definíciou 5) funkcií dvoch premenných v učebnom texte si vyberte dva z grafy a pomocou Sage vykreslite graf v 3D priestore i príslušný vrstevnicový graf v 2D rovine.**

# %% [markdown]
# ---
#
# **5. Podľa úvahy v Príklade 11 nájdite taký bod v trojrozmernom priestore, v ktorom funkčná hodnota funkcie $f(x,y,z)=\dfrac{x^2+z+3\sin y}{x+2y-z}$ je blízka nule (menej ako $0.1$) a tiež nájdite taký bod, v ktorom funkčná hodnota tejto funkcie je veľká (viac ako $100 000$). Využite Sage na experimentovanie.**

# %% [markdown]
# ---
#
# **6. Na základe úvah (za Príkladom 14) v učebnom texte vykreslite do jedného obrázka ale rôznymi farbami grafy funkcií $z=\sqrt{1-x^2-y^2}$ a $z=-\sqrt{1-x^2-y^2}$.**

# %% [markdown]
# ---
#
# **7. Z galérie kvadratických plôch (pred Definíciou 6) v učebnom texte si vyberte dve plochy a vykreslite ich pomocou Sage.**

# %% [markdown]
# ---
#
# **8. Aké <span style="color:red"> konkrétne </span> otázky máte k náplni študijných materiálov, ktoré by ste chceli na hodine prediskutovať?**

# %% [markdown]
# **Autor:** Andrej Gajdoš  <br>
# *[Ústav matematických vied](https://www.upjs.sk/prirodovedecka-fakulta/ustav/umv/), [Prírodovedecká fakulta](https://www.upjs.sk/prirodovedecka-fakulta/), Univerzita Pavla Jozefa Šafárika v Košiciach,* <br>
# email: [andrej.gajdos@upjs.sk](mailto:andrej.gajdos@upjs.sk)
# ***
# **_Tento materiál vznikol za podpory grantu VVGS-2021-1758._**
# ***
#
# **<font size=6 color=green> MTIb: Téma 11 - Funkcie viacerých premenných III.: úlohy </font>**

# %% [markdown]
# ---
#
# **1. Vo vzdialenosti $x$ metrov od pláže je cena pozemku o rozlohe $a$ metrov štvorcových,  v dolároch rovná $f(a,x)$.**
#
# **a) V akých jednotkách je $f_a(a,x)$ ?**
#
# **b) Čo prakticky znamená hodnota $f_a(1000,300)=3$ ?**
#
# **c) V akých jednotkách je $f_x(a,x)$ ?**
#
# **d) Čo prakticky znamená hodnota $f_x(1000,300)=-2$ ?**
#
# **e) Čo je lacnejšie: $1005$ stôp štvorcových pozemku, ktorý je $305$ metrov od pláže alebo $998$ metrov štvorcových pozemku, ktorý je vzdialený $295$ metrov od pláže? Zdôvodnite svoju odpoveď.**

# %% [markdown]
# ---
#
# **2. Určte totálne diferenciály pre nasledujúce funkcie:**
#
# $$\text{a) } f(x,y)=x^2e^{5y}, \qquad \text{b) } z=x\sin(xy), \qquad \text{c) } f(x,y)=x\cos(2x).$$

# %% [markdown]
# ---
#
# **3. Študent dostal za úlohu nájsť rovnicu dotykovej roviny k povrchu danému rovnicou $z=x^3-y^2$ v bode $[x,y]=[2,3]$. Odpoveď študenta bola $z=3x^2(x-2)-2y(y-3)-1$.**
#
# **a) Na prvý pohľad, ako zistíte, že je to nesprávne riešenie?**
#
# **b) Akú chybu urobil študent?**
#
# **c) Nájdite správne riešenie úlohy.**

# %% [markdown]
# ---
#
# **4. Nájdite rovnicu dotykovej roviny ku grafu funkcie $f(x,y)$ v bode $T$, ak:**
#
# $$\text{a) } f(x,y)=-2x^4+y^6,\ T=(2,1,?); \qquad \text{b) } f(x,y)=\frac{x}{y},\ T=(2,?,-1);$$
#
# $$\text{c) } f(x,y)=\ln(1+x+y),\ T=(?,0,0); \qquad \text{d) } f(x,y)=\sqrt{x^2+y^2}-xy,\ T=(3,4,?).$$

# %% [markdown]
# ---
#
# **5. Pomocou diferenciálu nájdite približnú hodnotu čísla $1.04^3+1.05^3$.**

# %% [markdown]
# ---
#
# **6. Pravý kruhový valec má polomer 50 cm a výšku 100 cm. Pomocou diferenciálov odhadnite zmenu objemu valca, ak sa jeho výška a polomer zvýšia o 1 cm.**

# %% [markdown]
# ---
#
# **7. V miestnosti je teplota daná funkciou $T=f(x,t)$ stupňov Celzia, kde $x$ je vzdialenosť od ohrievača (v metroch) a $t$ je uplynutý čas (v minútach) od zapnutia ohrievača. Osoba stojaca $3$ metre od ohrievača $5$ minút po jeho zapnutí pozoruje nasledovné: (1) Teplota sa zvyšuje o $1.2^\circ C$ za minútu a (2) Keď sa vzdialite od ohrievača, teplota sa zníži o $2^\circ C$ na meter (pri konštantnej hodnote času). Odhadnite, o koľko by bolo chladnejšie alebo teplejšie $2.5$ metra od ohrievača po $6$ minútach od jeho zapnutia.**

# %% [markdown]
# ---
#
# **8. Nájdite gradienty (prípadne v konkrétnom bode) uvedených funkcií:**
#
# $$\text{a) } f(\alpha,\beta)=\sqrt{5\alpha^2+\beta}; \quad \text{b) } f(r,h)=\pi r^2h; \quad \text{c) } f(x,y)=\ln\left(x^2+y^2\right);$$
#
# $$\text{d) } z=x\frac{e^y}{x+y}; \quad \text{e) } f(x,y)=\sin\left(x^2\right)+\cos y,\, \left[\frac{\sqrt{\pi}}{2},0\right]; \quad \text{f) } f(x,y)=\sqrt{\mathrm{tg}(x)+y},\,[0,1].$$

# %% [markdown]
# ---
#
# **9. S využitím grafov (aj vrstevnicových) vykreslených pomocou Sage, skúste odhadnúť v ktorých bodoch nasledujúce funkcie nebudú diferencovateľné:**
#
# $$\text{a) } z=-\sqrt{x^2+y^2};\quad \text{b) } z=\sqrt{(x+1)^2+y^2};\quad \text{c) } z=|x|+|y|;\quad \text{d) } z=|x+2|-|y-3|;$$
#
# $$\text{e) } z=e^{-\left(x^2+y^2\right)};\quad \text{f) } z=x^{1/3}+y^2;\quad \text{g) } z=|x-3|^2+y^3;\quad \text{h) } z=(\sin x)(\cos|y|);$$
#
# $$\text{i) } z=4+\sqrt{(x-1)^2+(y-2)^2};\quad \text{j) } z=1+\left((x-1)^2+(y-2)^2\right)^2.$$

# %% [markdown]
# ---
#
# **10. Nasledujúcich 6 obrázkov zobrazuje vrstevnicové grafy okolo kritického bodu $P$ pre šesť rôznych funkcií. V ktorom prípade je v bode $P$ lokálne maximum, lokálne minimu, sedlový bod?**
#
# ![vrstevnice_kriticky_bod.PNG](attachment:vrstevnice_kriticky_bod.PNG)

# %% [markdown]
# ---
#
# **11. Ktorý z bodov $A,B,C$ na nasledujúcom obrázku sa javí ako kritický bod? Klasifikujte kritické body.**
#
# **V ktorom z bodov $D,E,F,G$ na nasledujúcom obrázku sa javí byť lokálne maximum, lokálne minimum, sedlový bod?**
#
# ![lokalne_extremy_vrstevnice.PNG](attachment:lokalne_extremy_vrstevnice.PNG)

# %% [markdown]
# ---
#
# **12. Nájdite všetky lokálne extrémy nasledujúcich funkcií $f(x,y)$, ak:**
#
# $$\text{a) } f(x,y)=x^2+y^2-xy-x-y+2; \qquad \text{b) } f(x,y)=(y-x-2)^2;$$
#
# $$\text{c) } f(x,y)=x^3 +y^3; \qquad \text{d) } f(x,y)=x^2y^2(1-x-y);$$
#
# $$\text{e) } f(x,y)=(x^2+y)\sqrt{\mathrm{e}^y}; \qquad \text{f) } f(x,y)=x^2-y^2+2x-2y;$$
#
# $$\text{g) } f(x,y)=5xy+\frac{25}{x}+\frac{8}{y},\ x>0,\ y>0; \qquad \text{h) } f(x,y)=3\ln\frac{x}{6}+2\ln y+\ln(12-x-y).$$

# %% [markdown]
# ---
#
# **13. Raketa má navádzacie zariadenie, ktore je citlivé na teplotu $t$ (v $^\circ C$) a na vlhkosť $h$. Dosah $R$ (v km), v ktorom je možné raketu riadiť, je daný vzťahom**
#
# $$R=27800-5t^2-6ht-3h^2+400t+300h.$$
#
# **Aké sú optimálne atmosférické podmienky pre riadenie rakety?**

# %% [markdown]
# ---
#
# **$\star$ 14. Uzavretá obdĺžniková skrinka so stenami rovnobežnými so súadnicovými rovinami má jeden spodný roh v počiatku súradnicovej sústavy a protiľahlý horný roh v prvom oktante v rovine $3x + 2y + z = 1$. Aký je maximálny objem takejto skrinky?**

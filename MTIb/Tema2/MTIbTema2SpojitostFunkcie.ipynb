# %% [markdown]
# **Autor:** Andrej Gajdoš  <br>
# *[Ústav matematických vied](https://www.upjs.sk/prirodovedecka-fakulta/ustav/umv/), [Prírodovedecká fakulta](https://www.upjs.sk/prirodovedecka-fakulta/), Univerzita Pavla Jozefa Šafárika v Košiciach,* <br>
# email: [andrej.gajdos@upjs.sk](mailto:andrej.gajdos@upjs.sk)
# ***
# **_Tento materiál vznikol za podpory grantu VVGS-2021-1758._**
# ***
#
# **<font size=6 color=gold> MTIb: Téma 2 - Spojitosť funkcie </font>**

# %% [markdown]
# ***
# <a id=spojitost></a>
#  # <font color=brown> Spojitosť funkcie</font>

# %% [markdown]
# Existuje **niekoľko intuitívnych pohľadov na spojitosť funkcie**. Zosumarizujme si ich ešte pred tým, než vyslovíme exaktnú definíciu spojitosti. Všimnime si ale, že budeme rozlišovať spojitosť funkcie v bode a spojitosť funkcie na (uzavretom) intervale. Spojitosť funkcie na (uzavretom) intervale budeme neskôr definovať pomocou spojitosti funkcie v bode.
#
# * Zhruba povedané, funkcia je spojitá na intervale, ak jej graf neobsahuje žiadne "prerušenia", "skoky" či "diery" v rámci daného intervalu. Inými slovami, funkcia je spojitá na intervale, keď dokážeme jej graf nakresliť bez zdvihnutia ceruzky z papiera (teda akoby jedným ťahom).
#
#
# * Funkcia $f$ je spojitá v bode $x_0$ vtedy, keď $x_1$ je blízko $x_0$, tak aj $f(x_1)$ je blízko $f(x_0)$. Inými slovami blízke body (hodnoty) $x_1$ a $x_0$ sa zobrazia pomocou funkcie $f$ blízko seba tzn. $f(x_1)$ je blízko $f(x_0)$. Ešte ináč povedané, malé zmeny (chyby resp. odchýlky) v nezávislej premennej $x$ vedú k malým zmenám (chybám resp. odchýlkam) funkčných hodnôt $f(x)$.
#
# Nech $f(x)=x^2$ a predpokladajme, že vieme o spojitosti funkcie $x^2$. Chceme zistiť čomu je rovné $f(\pi)$. Uvedomme si, že číslo $\pi$ má nekonečne veľa číslic za desatinnou bodkou resp. čiarkou, a teda nie je možné ho celé dosadiť do funkcie, tzn. nevieme úplne presne určiť $f(\pi)$. Vďaka spojitosti ale máme zaručené, že ak vezmeme napr. číslo $3.14$, ktoré je blízko čísla $\pi$, tak potom $f(3.14)$ bude hodnota blízka hodnote $f(\pi)$, preto stačí vypočítať $f(3.14)$, čo nie je problém. Ak by sme chceli určiť hodnotu $f(\pi)$ presnejšie, tak stačí dosadiť do $f(x)$ miesto $x$ číslo bližšie k $\pi$, než je číslo $3.14$. Takto vieme určiť hodnotu $f(\pi)$ s ľubovoľnou (vopred predpísanou) presnosťou resp. chybou.

# %% [markdown]
# ---
#
# #### <font color=blue> Príklad 1 </font>

# %%
x = var('x') 
f1 = 3*x^3-x^2+2*x
f2 = 1/x 
kwds = {'fontsize':10} 
p1 = plot(f1(x), (x, -2, 2), axes_labels=['$x$', '$y$'], axes_labels_size = 1) + text(r"$f_1(x)=3x^3-x^2+2x$", (6, 28), color='blue',**kwds) 
p2 = plot(f2(x), (x, -2, -0.1), axes_labels=['$x$', '$y$'], axes_labels_size = 1) + plot(f2(x), (x, 0.1, 2), axes_labels=['$x$', '$y$'], axes_labels_size = 1) + text(r"$f_2(x)=\dfrac{1}{x}$", (1.5, 10), color='blue',**kwds) 
p3 = line([(0.1,7),(1,7)], color = 'blue', axes_labels=['$x$ (hodiny)', '$y$ (doláre)'], axes_labels_size = 1.0) + line([(1.1,14),(2,14)], color = 'blue') + line([(2.1,21),(3,21)], color = 'blue') + circle((0,7), 0.1, color = 'blue') + circle((1, 7), 0.1, color='blue', fill=True) + circle((1,14), 0.1, color = 'blue') + circle((2, 14), 0.1, color='blue', fill=True) + circle((2,21), 0.1, color = 'blue') + circle((3, 21), 0.1, color='blue', fill=True) + text(r"$p(x)$", (3, 22), color='blue',**kwds) 
G = graphics_array([p1,p2,p3])
# G.show(figsize=[10, 4])  
G.show(figsize=[12, 5], aspect_ratio=0.5)
# Out:
# Graphics Array of size 1 x 3

# %% [markdown]
# Pozrime sa na príklady funkcií $f_1$, $f_2$, $p$, ktorých grafy máme vykreslené. Funkcia $f_1$ je spojitá na ľubovoľnom intervale. Funkcia $f_2$ nie je definovaná v bode $0$. Je spojitá na takom intervale, ktorý neobsahuje $0$. Funkcia $p$ vyjadruje nasledovné: Spoločnosť prenajíma autá za 7 dolárov na hodinu, ale aj prenájom na menej ako hodinu stojí 7 dolárov (vždy sa platí za celú hodinu); 14 dolárov sa platí za prenájom auta na viac ako jednu a menej ako dve hodiny atď. Ak je $p(x)$  cena za výpožičku auta trvajúcu $x$ hodín, potom je jej graf (viď graf $p(x)$ hore) postupnosťou "schodov". Táto funkcia nie je spojitá na žiadnom otvorenom intervale obsahujúcom kladné celé číslo, pretože graf v týchto bodoch preskočí - nastáva tu skok (viď prázdne a plné krúžky v grafe). Všimnime si ešte, že $p(0.99) = p(1) = 7$ dolárov, zatiaľ čo $p(1.01) = 14$ dolárov, pretože keď prekročíme jednu hodinu (čas zapožičania auta), cena vyskočí na 14 dolárov. Takže malý časový rozdiel môže viesť k významnému rozdielu v nákladoch. Preto $p$ nie je spojitá v $x = 1$. Ako vidíme z grafu, znamená to tiež, že nie je spojitá v žiadnom otvorenom intervale obsahujúcom bod $x = 1$.

# %% [markdown]
# ---

# %% [markdown]
# ---
#
# #### <font color=blue> Príklad 2 </font>

# %% [markdown]
# Pri štúdiu limít sme nadobudli intuíciu, že **limita popisuje správanie sa funkcie v okolí (v blízkosti) nejakého bodu tzn. limita udáva, k čomu sa blíži funkcia (jej funkčné hodnoty), keď sa blížime ku konkrétnemu bodu po osi $x$**. Napr. $\lim\limits_{x\to1} g(x)=3$ nám hovorí, že keď $x\to1$ tak $g(x)\to3$ resp. keď je $x$ blízko k $1$, tak $g(x)$ je blízko k $3$. Avšak, ako sme už videli v predošlej téme, **limita nemusí dobre vystihovať, čomu je rovná samotná funkčná hodnota**  $g(1)$. Mohlo by sa totiž stať, že napr. funkcia $g(x)$ sa v okolí bodu $1$ blíži k hodnote $3$ ale samotné $g(1)$ je ďaleko od hodnoty $3$ (nastáva "skok" v grafe funkcie), pozrime sa na nasledujúci graf - funkcia je konštantná s hodnotou $3$,  s výnimkou bodu $1$, kde nadobúda funkcia hodnotu $4$ (je tu tzv. "skok").

# %%
x = var('x') 
kwds = {'fontsize':12} 
p = plot(3, (x, -4, 0.95), axes_labels=['$x$', '$y$'], axes_labels_size = 1, ymin = 0, ymax = 4) + plot(3, (x, 1.05, 4), axes_labels=['$x$', '$y$'], axes_labels_size = 1, ymin = 0, ymax = 4.2) + circle((1, 3), 0.05, color='blue') + circle((1, 4), 0.05, color='blue', fill=True) + text(r"$g(x)$", (2, 3.5), color='blue',**kwds) 
show(p, figsize=4)
# Out:
# Graphics object consisting of 5 graphics primitives

# %% [markdown]
# Ináč povedané, **ak funkcia nie je spojitá, potom malej zmene premennej $x$ odpovedá veľká zmena funkčnej hodnoty $g(x)$**. Čiže ak je funkcia nespojitá v bode $x_0$ a vezme $x_1$ blízke $x_0$, tak $g(x_1)$ bude ďaleko od $g(x_0)$. Keď sa pozrieme konkrétne na graf funkcie $g$ a položíme $x_0=1$, $x_1=0.99$, tak máme $f(x_0)=f(1)=4$ a $f(x_1)=f(0.99)=3$. V tejto časti sa budeme zaoberať takými funkciami, u ktorých toto "nepekné" správanie nenastáva vďaka spojitosti.

# %% [markdown]
# ---

# %% [markdown]
# ---
#
# #### <font color=blue> Príklad 3 </font>

# %% [markdown]
# Kvôli názornosti a lepšiemu uchopeniu pojmu spojitosti funkcie sa ešte pozrime na nasledujúce tri príklady funkcií $h_1$, $h_2$, $h_3$. Tieto **tri funkcie** majú okrem iného spoločné aj to, že **majú rovnakú limitu v bode** $x_0=1$. **Avšak funkcia $h_1$ v bode $x_0=1$ definovaná nie je**, čo spôsobuje "dieru" v jej grafe práve v tomto bode. **O takej funkcii prehlásime, že nie je spojitá v bode $1$**. Pri funkcii $h_2$ môžeme pozorovať, že zatiaľ čo $\lim\limits_{x\to1}h_2(x)=3$, tak $h_2(1)=2$, a teda **limita v bode $1$ sa nerovná funkčnej hodnote v bode $1$**. **Aj v tomto prípade povieme, že funkcia nie je spojitá v bode $x_0=1$**. Na druhej strane funkcia $h_3$ sa zdá, akoby mala najlepšie vlastnosti, lebo jej **limita a funkčná hodnota v bode $x_0=1$ sa rovnajú**, t.j. $\lim\limits_{x\to1}h_3(x)=3=h_3(1)$. V grafe funkcie $h_3$ nie je žiadna "diera" ani "skok" v bode $x_0=1$. **O takej funkcii povieme, že je spojitá v bode $1$.**

# %%
x = var('x') 
h = -(x-1)^2+3 
kwds = {'fontsize':12} 
p1 = plot(h, (x, -0.5, 0.95), axes_labels=['$x$', '$y$'], axes_labels_size = 1) + plot(h, (x, 1.05, 3), axes_labels=['$x$', '$y$'], axes_labels_size = 1) + circle((1,3), 0.05, color = 'blue') + text(r"$h_1$", (1.5, 3.2), color='blue',**kwds) 
p2 = plot(h, (x, -0.5, 0.95), axes_labels=['$x$', '$y$'], axes_labels_size = 1) + plot(h(x), (x, 1.05, 3), axes_labels=['$x$', '$y$'], axes_labels_size = 1) + circle((1,3), 0.05, color = 'blue') + circle((1, 2), 0.05, color='blue', fill=True) + text(r"$h_2$", (1.5, 3.2), color='blue',**kwds) 
p3 = plot(h, (x, -0.5, 0.95), axes_labels=['$x$', '$y$'], axes_labels_size = 1) + plot(h(x), (x, 1.05, 3), axes_labels=['$x$', '$y$'], axes_labels_size = 1) + circle((1, 3), 0.05, color='blue', fill=True) + text(r"$h_3$", (1.5, 3.2), color='blue',**kwds) 
G = graphics_array([p1,p2,p3])
G.show(figsize=[8, 3])  
# G.show(figsize=[12, 5], aspect_ratio=0.5) 
# show(G)
# Out:
# Graphics Array of size 1 x 3

# %% [markdown]
# ---

# %% [markdown]
# Predchádzajúce úvahy sú formálne zhrnuté v Definícii 1.

# %% [markdown]
# ---
#
# ### <font color=red> Definícia 1 </font>
#
# Nech funkcia $f:\ \mathbb{R} \to \mathbb{R}$ je definovaná na nejakom okolí bodu $x_0$ (aj v bode $x_0$). Hovoríme, že $f$ je **_spojitá_** v bode $x_0$, ak $\lim\limits_{x \to x_0} f(x) = f(x_0)$.
#
# Funkciu $f:\ \mathbb{R} \to \mathbb{R}$ definovanú na nejakom intervale $\langle x_0, x_0+\delta)$  nazveme **_spojitou sprava_** v bode $x_0$ ak $\lim\limits_{x \to x_0^+} f(x) = f(x_0)$.
#
# Funkciu $f:\ \mathbb{R} \to \mathbb{R}$ definovanú na nejakom intervale $(x_0-\delta, x_0\rangle$  nazveme **_spojitou zľava_** v bode $x_0$ ak $\lim\limits_{x \to x_0^-} f(x) = f(x_0)$.
#
# ---

# %% [markdown]
# Uvádzame príklad funkcie spojitej sprava a súčasne nespojitej zľava v bode $x_0=1$ (graf vľavo) a tiež príklad funkcie spojitej zľava a súčasne nespojitej sprava v bode $x_0=1$ (graf vpravo).

# %%
x = var('x') 
kwds = {'fontsize':12} 
p1 = plot(sqrt(x), (x, 0, 0.95), axes_labels=['$x$', '$y$'], axes_labels_size = 1) + plot(x^2+1, (x, 1.02, 2), axes_labels=['$x$', '$y$'], axes_labels_size = 1) + circle((1,1), 0.05, color = 'blue') + circle((1,2), 0.05, color = 'blue', fill=True) 
p2 = plot(x^2, (x, 0, 0.98), axes_labels=['$x$', '$y$'], axes_labels_size = 1) + plot(sqrt(x)+1, (x, 1.05, 2), axes_labels=['$x$', '$y$'], axes_labels_size = 1) + circle((1,1), 0.05, color = 'blue', fill=True) + circle((1, 2), 0.05, color='blue') 
G = graphics_array([p1,p2])
G.show(figsize=[10, 4])
# Out:
# Graphics Array of size 1 x 2

# %% [markdown]
# ---
#
# #### Poznámka 1
#
# * Ak je funkcia $f$ spojitá v bode $x_0$, potom platí:
#     1. $x_0\in\mathcal{D}(f)$;
#     2. funkcia je definovaná na nejakom okolí (**nie prstencovom! rozdiel oproti limite!**) bodu $x_0$, t.j. existuje číslo $\delta>0$ také, že $(x_0-\delta,x_0+\delta)\subset\mathcal{D}(f)$;
#     3. existuje vlastná limita $\lim\limits_{x\to x_0} f(x)=A$;
#     4. $A=f(x_0)$.
#
# * Bod, v ktorom funkcia $f$ nie je spojitá (neplatí aspoň jeden zo štyroch bodov uvedených vyššie) sa nazýva **_bod nespojitosti_** funkcie $f$.
#
# * **Spojitosť funkcie $f$ v bode $x_0$, definovanej na nejakom okolí bodu $x_0$, je možné vyjadriť formálne (podobne ako limitu) aj takto:**
#
# $$\left(\forall \varepsilon > 0\right)\left(\exists \delta > 0\right)\left(\forall x \in (x_0 - \delta,x_0+\delta)\right)\ |f(x)-A| < \varepsilon$$
#
#     resp.
#
# $$\left(\forall \varepsilon > 0\right)\left(\exists \delta > 0\right)\left(\forall x\in\mathcal{D}(f):|x-x_0| <\delta\right)\ |f(x)-A| < \varepsilon.$$
#
#
# * **Všimnime si rozdiel!** V definícii limity v bode $x_0$ nehrali samotné $x_0$ a $f(x_0)$ dôležitú úlohu, podstatné bolo správanie sa funkcie na prstencovom okolí bodu $x_0$ (bez $x_0$) a funkcia v bode $x_0$ nemusela byť definovaná, stačilo, že bola definovaná na prstencovom okolí (s možnou výnimkou bodu $x_0$). Na druhej strane, pri definovaní spojitosti v bode $x_0$ sa vyžaduje, aby funkcia bola definovaná aj v samotnom bode $x_0$ (resp. na jeho okolí, už nestačí len prstencové!), a teda $x_0$ aj $f(x_0)$ tu hrajú dôležitú úlohu.
#
#
# * Limitu v bode $x_0$ spojitej funkcie $f$ určíme jednoducho ako $f(x_0)$ (Napr. Veta 3 o výpočte limity polynomickej funkcie v téme 1).
#
#
# * **Väčšina (elementárnych) funkcií, s ktorými sme sa už stretli, sú spojité všade tam, kde sú definované.** Napríklad exponenciálne funkcie, polynómy, sínus a kosínus sú všade spojité. Racionálne funkcie sú spojité na akomkoľvek intervale, v ktorom ich menovatele nie sú nulové. Funkcie vytvorené sčítaním, násobením alebo zložením spojitých funkcií sú tiež spojité (viď ďalej Veta 2). **Limity všetkých uvedených spojitých funkcií v bodoch ich definičného oboru je teda možné rátať ako funkčné hodnoty v daných bodoch.**
#
# ---

# %% [markdown]
# Ďalšie vety prirodzene vyplývajú z toho, že spojitosť je definovaná ako limita a veľmi pripomínajú vlastnosti limity funkcie v bode z témy 1.

# %% [markdown]
# ---
#
# ### <font color=green> Veta 1 </font>
#
# Funkcia $f$ je spojitá v bode $x_0$ práve vtedy, keď je v bode $x_0$ spojitá sprava aj zľava.
#
# ---

# %% [markdown]
# ---
#
# ### <font color=green> Veta 2 </font>
#
# Ak funkcie $f,g$ sú spojité (spojité sprava resp. zľava) v bode $x_0$ a $c \in \mathbb{R}$, tak sú v bode $x_0$ spojité (spojité sprava resp. zľava) aj funkcie $|f|,\ c\cdot f,\ f \pm g,\ f \cdot g$. Ak $g(x_0) \neq 0$, tak v bode  $x_0$ je spojitá (spojitá sprava resp. zľava) aj funkcia $\dfrac{f}{g}$.
#
# ---

# %% [markdown]
# <font color=orange> Uveďte príklad pre ilustráciu Vety 2. Vymyslite konkrétnu funkciu resp. funkcie $f,g$, zvoľte konkrétny bod $x_0$ a zdôvodnite, prečo výsledná funkcia je v bode $x_0$ spojitá. Pomôžte si grafmi v Sage a tiež tvrdeniami o limitách z témy 1.</font>

# %% [markdown]
# ---
#
# ### <font color=green> Veta 3 </font>
#
# Ak funkcia $g$ je spojitá (spojitá sprava resp. zľava) v bode $x_0$, $g(x_0) = z$ a funkcia $f$ je spojitá (spojitá sprava resp. zľava) v bode $z$, tak zložená funkcia $f \circ g = f\left(g(x)\right)$ je spojitá (spojitá sprava resp. zľava) v bode $x_0$.
#
# ---

# %% [markdown]
# <font color=orange> Uveďte príklad pre ilustráciu Vety 3. Vymyslite konkrétne funkcie $f$ a $g$, zvoľte konkrétny bod $x_0$ a zdôvodnite, prečo výsledná funkcia je v bode $x_0$ spojitá. Pomôžte si grafmi v Sage a tiež tvrdeniami o limitách z témy 1.</font>

# %% [markdown]
# ---
#
# #### Poznámka 2
#
# * V prípade zloženia spojitých funkcií je možné rátať limitu celkom pohodlne a to tak, že limitou môžeme "vojsť" do funkcie $f$, ktorá je spojitá v bode $z$, pričom $z=\lim\limits_{x\to x_0}g(x)$, t.j.
# <br/>
# $$\lim\limits_{x\to x_0}f\left(g(x)\right)=f\left(\lim\limits_{x\to x_0}g(x)\right).$$
#
#
# * Presnejšie teda platí tvrdenie, že ak existuje $\lim\limits_{x\to x_0}g(x)=z$ a funkcia $f$ je spojitá v bode $z$, potom v bode $x_0$ existuje limita zloženej funkcie $f\left(g(x)\right)$ a platí $\lim\limits_{x\to x_0}f\left(g(x)\right)=f(z)$.
#
#
# * Príklad:
# $$\lim\limits_{x\to 2} e^{-x^2}= e^{\lim\limits_{x\to 2}-x^2}=e^{-2^2}=e^{-4}=\frac{1}{e^4}\approx0.0183,$$
# pričom $f\left(g(x)\right)=e^{-x^2}$, $g(x)=-x^2$, $z=\lim\limits_{x\to 2}g(x)=\lim\limits_{x\to 2}(-x^2)=-4$ a funkcia $f(x)=e^{x}$ je spojitá v bode $z=-4$.
#
# ---

# %% [markdown]
# ---
#
# ### <font color=green> Veta 4 </font>
#
# Nech funkcia $f$ je spojitá v bode $x_0$. Potom $f$ je ohraničená na nejakom okolí $x_0$.
#
# ---

# %% [markdown]
# Inými slovami, Veta 4 v podstate hovorí, že ak je funkcia spojitá v bode $x_0$, potom musí existovať (otvorený) interval obsahujúci bod $x_0$ a na tomto intervale funkcia nemôže ubiehať do plus/mínus nekonečna.

# %% [markdown]
# ---
#
# #### <font color=blue> Príklad 4 </font>
#
# Funkcia $f(x)=(x-3)^2$ je polynomická funkcia (druhého stupňa), je teda spojitá na celej reálnej osi a tým pádom napr. aj v bode $x_0=3$. Podla Vety 4 existuje okolie bodu $3$, na ktorom je táto funkcia ohraničená. Máme nespočetne veľa možností ako zvoliť toto okolie, pre jednoduchosť môžeme vziať napr. interval $(2,4)$, na ktorom je funkcia $f(x)=(x-3)^2$ ohraničená napr. hodnotou $0$ zdola a hodnotou $1$ zhora (resp. graf funkcie ohraničený priamkami $y=0$, $y=1$). Mohli by sme však vziať aj iné ohraničenia napr. $y=0$ a $y=2$ alebo $y=-1$ a $y=1$ atď.

# %%
x = var('x') 
kwds = {'fontsize':12} 
plot((x-3)^2, (x, 1, 5), axes_labels=['$x$', '$y$'], axes_labels_size = 1, figsize=5) + line([(0,1),(5,1)], color = 'red') + line([(0,2),(5,2)], color = 'red')  + line([(0,-1),(5,-1)], color = 'red') + line([(0,2),(5,2)], color = 'red') + line2d([(2.08,0),(3.92,0)], color = 'green', thickness=3) + circle((2,0), 0.05, color = 'green', fill=True) + circle((4,0), 0.05, color = 'green', fill=True) + line2d([(2,0.05),(2,4)], color = 'green', linestyle='dashed') + line2d([(4,0.05),(4,4)], color = 'green', linestyle='dashed') + text(r"$f(x)=(x-3)^2$", (6, 3), color='blue',**kwds) + text(r"$y=1$", (1, 1.2), color='red',**kwds) + text(r"$y=2$", (1, 2.2), color='red',**kwds) + text(r"$y=-1$", (1, -0.8), color='red',**kwds)
# Out:
# Graphics object consisting of 14 graphics primitives

# %% [markdown]
# ---

# %% [markdown]
# ---
#
# ### <font color=green> Veta 5 </font>
#
# Nech funkcia $f$ je spojitá v bode $x_0$ a $f(x_0) \neq 0$. Potom  existuje okolie $U$ bodu $x_0$ také, že pre všetky $x \in U$ platí $\mathrm{sgn}(f(x)) = \mathrm{sgn}(f(x_0))$, kde $\mathrm{sgn}(y)$ je funkcia nadobudajúca hodnoty iba $\{-1,0,1\}$ podľa toho, či je $y<0$, $y=0$ alebo $y>0$.
#
# ---

# %% [markdown]
# Funkcia $\mathrm{sgn}(x)$ vlastne určuje "znamienko" hodnoty $x$ a Veta 5 teda hovorí o tom, že ak je funkcia $f$ spojitá v bode $x_0$, potom existuje okolie bodu $x_0$ také, že funkcia $f$ na ňom nemení znamienko (všetky funkčné hodnoty $f(x)$ na tomto okolí sú buď kladné alebo záporné a ich znamienko je totožné so znamienkom hodnoty $f(x_0)$).

# %% [markdown]
# ---
#
# #### <font color=blue> Príklad 5 </font>
#
# Funkcia $f(x)=\cos x$ je spojitá na $\mathbb{R}$ a teda aj v bode $x_0=0$. Zrejme $\cos\,(0)=1\neq0$, preto podľa Vety 5 existuje okolie $U$ bodu $x_0=0$ také, že pre všetky $x$ z tohto okolia sú znamienka hodnôt $f(x)$ rovnaké ako znamienko hodnoty $f(x_0)=f(0)$. Inými slovami, pre všetky $x$ z okolia $U$ by malo platiť $\mathrm{sgn}(f(x))=\mathrm{sgn}(f(x_0))=\mathrm{sgn}(f(0))=\mathrm{sgn}(1)=1$ (lebo $1>0$). Za okolie $U$ stačí vziať napr. interval $\left(-\dfrac{\pi}{4},\dfrac{\pi}{4}\right)$ t.j. $U=\left(-\dfrac{\pi}{4},\dfrac{\pi}{4}\right)$ (viď graf pod textom - zelenou farbou). Ako je vidieť z grafu, tak ako tvrdí Veta 5, všetky znamienka funkčných hodnôt $f(x)$ na otvorenom intervale $U$ sú rovnaké - v našom prípade kladné (viď zelenou farbou vymedzená oblasť grafu).

# %%
x = var('x') 
kwds = {'fontsize':10} 
plot(cos(x), (x, -4, 4), axes_labels=['$x$', '$y$'], axes_labels_size = 1) + line2d([(-pi/4+0.08,0),(pi/4-0.08,0)], color = 'green', thickness=3) + circle((-pi/4,0), 0.05, color = 'green') + circle((pi/4,0), 0.05, color = 'green') + line2d([(-pi/4,0.05),(-pi/4,1)], color = 'green', linestyle='dashed') + line2d([(pi/4,0.05),(pi/4,1)], color = 'green', linestyle='dashed') + text(r"$f(x)=\cos\,x$", (1.6, 0.8), color='blue',**kwds)
# Out:
# Graphics object consisting of 7 graphics primitives

# %% [markdown]
# ---

# %% [markdown]
# Nasledujúci príklad nám ilustruje situáciu, keď **z nespojitej funkcie môžeme "vyrobiť" spojitú funkciu**. Ide o to, že ak existuje vlastná limita $\lim\limits_{x\to x_0} f(x)=A$ ale bod $x_0$ nepatrí do definičného oboru funkcie $f$, potom môžeme funkciu $f$ dodefinovať v bode $x_0$ tak, aby bola spojitá v tomto bode. Z (nespojitej) funkcie $f$ vytvoríme novú (spojitú) funkciu $\tilde{f}$ takto:
#
# $$\tilde{f}=\begin{cases}
# f(x) & \quad \text{pre } x\neq x_0, \\
# A & \quad \text{pre } x=x_0.
# \end{cases}$$

# %% [markdown]
# ---
#
# #### <font color=blue> Príklad 6 </font>
#
# Nech $h(x)=3$ pre $x\in\mathbb{R}\backslash\{2\}$. Ak je to možné, dodefinujte funkciu na spojitú.
#
# <ins> Riešenie: <ins/>
#
# Funkcia $h(x)$ nie je definovaná v bode $x_0=2$ (prázdny krúžok v grafe) a všade inde nadobúda hodnotu $3$ (viď graf nižšie). Zrejme však platí (napr. podľa Vety 1 z témy 1) $\lim\limits_{x\to2} h(x)=3$, a preto môžeme dodefinovať funkciu $h$ na spojitú funkciu nasledovne:
#
# $$\tilde{h}=\begin{cases}
# h(x) & \quad \text{pre } x\neq 2, \\
# 3 & \quad \text{pre } x=2.
# \end{cases}$$
#
# Je to to isté, ako keď by sme položili $\tilde{h}(x)=3$; $\forall x\in\mathbb{R}$.

# %%
x = var('x') 
kwds = {'fontsize':12} 
p1 = plot(3, (x, -4, 1.95), axes_labels=['$x$', '$y$'], axes_labels_size = 1, ymin = 0, ymax = 4) + plot(3, (x, 2.05, 4), axes_labels=['$x$', '$y$'], axes_labels_size = 1, ymin = 0, ymax = 4.2) + circle((2, 3), 0.05, color='blue') + text(r"$h(x)$", (2, 3.5), color='blue',**kwds) 
p2 = plot(3, (x, -4, 1.95), axes_labels=['$x$', '$y$'], axes_labels_size = 1, ymin = 0, ymax = 4) + plot(3, (x, 2.05, 4), axes_labels=['$x$', '$y$'], axes_labels_size = 1, ymin = 0, ymax = 4.2) + circle((2, 3), 0.05, color='blue', fill = True) + text(r"$\tilde{h}(x)$", (2, 3.5), color='blue',**kwds) 
G = graphics_array([p1,p2])
G.show(figsize=[8, 3]) 
# show(G)
# Out:
# Graphics Array of size 1 x 2

# %% [markdown]
# ---

# %% [markdown]
# <font color=orange> Uvažujte funkciu $y=\dfrac{1}{x}$. Prečo túto funkciu nie je možné dodefinovať v bode $x_0=0$ na spojitú funkciu podobne ako v Príklade 6? Nápoveda: Pomocou Sage preskúmajte, čo sa deje s funkčnými hodnotami, keď sa blížia hodnoty $x$ k $x_0=0$ sprava a zľava. Aké sú jednostranné limity v bode $x_0=0$ ? Zároveň si pomôžte Príkladom 6 a komentárom nad ním. </font>

# %% [markdown]
# ---
#
# ### <font color=red> Definícia 2 </font>
#
# Hovoríme, že funkcia $f$ je **_spojitá na uzavretom intervale_** $\langle a,b \rangle$, ak je spojitá v každom bode $x_0 \in (a,b)$, spojitá v $a$ sprava a spojitá v $b$ zľava.
#
# ---

# %% [markdown]
# ---
#
# ### <font color=green> Veta 6 (Weierstrassova o ohraničenosti) </font>
#
# Nech funkcia $f$ je definovaná a spojitá na intervale $\langle a,b \rangle$. Potom $f$ je ohraničená na $\langle a,b\rangle$.
#
# ---

# %% [markdown]
# ---
#
# #### <font color=blue> Príklad 7 </font>
#
# Na ilustráciu Vety 6 stačí vziať napr. funkciu z Príkladu 4, t.j. $f(x)=(x-3)^2$ a za interval $\langle a, b \rangle$ vziať napr. interval $\langle 2, 4 \rangle$. Funkcia na intervale $\langle 2, 4 \rangle$ je zjavne spojitá a ohraničená (ohraničenosť zdola: funkčné hodnoty zdola ohraničené napr. hodnotou $0$ resp. graf funkcie zdola ohraničený priamkou $y=0$ alebo funkčné hodnoty zdola ohraničené napr. hodnotou $-1$ resp. graf funkcie zdola ohraničený priamkou priamkou $y=-1$ a pod.; ohraničenosť zhora: funkčné hodnoty zhora ohraničené napr. hodnotou $1$ resp. graf funkcie zhora ohraničený priamkou $y=1$ alebo funkčné hodnoty zhora ohraničené napr. hodnotou $2$ resp. graf funkcie zhora ohraničený priamkou priamkou $y=2$ a pod.).

# %%
x = var('x') 
kwds = {'fontsize':12} 
plot((x-3)^2, (x, 1, 5), axes_labels=['$x$', '$y$'], axes_labels_size = 1, figsize=5) + line([(0,1),(5,1)], color = 'red') + line([(0,2),(5,2)], color = 'red')  + line([(0,-1),(5,-1)], color = 'red') + line([(0,2),(5,2)], color = 'red') + line2d([(2.08,0),(3.92,0)], color = 'green', thickness=3) + circle((2,0), 0.05, color = 'green', fill=True) + circle((4,0), 0.05, color = 'green', fill=True) + line2d([(2,0.05),(2,4)], color = 'green', linestyle='dashed') + line2d([(4,0.05),(4,4)], color = 'green', linestyle='dashed') + text(r"$f(x)=(x-3)^2$", (6, 3), color='blue',**kwds) + text(r"$y=1$", (1, 1.2), color='red',**kwds) + text(r"$y=2$", (1, 2.2), color='red',**kwds) + text(r"$y=-1$", (1, -0.8), color='red',**kwds)
# Out:
# Graphics object consisting of 14 graphics primitives

# %% [markdown]
# ---

# %% [markdown]
# ---
#
# ### <font color=green> Veta 7 (Weierstrassova o maxime a minime) </font>
#
# Nech funkcia $f$ je definovaná a spojitá na uzavretom intervale $\langle a,b \rangle$. Potom $f$ nadobúda na $\langle a,b \rangle $ maximum a minimum, t.j.
#
# $$(\exists c,d \in \langle a,b \rangle)(\forall x \in \langle a,b\rangle )\ f(c) \leq f(x) \leq f(d).$$
#
# ---

# %% [markdown]
# ---
#
# #### <font color=blue> Príklad 8 </font>
#
# Pre lepšie pochopenie a vizualizáciu Vety 7 sa stačí pozrieť na graf z Príkladu 7. Maximum funkcie $f$ na intervale $\langle 2, 4 \rangle$ sa nadobúda dokonca v dvoch bodoch, t.j. v bode $d_1=2$ a $d_2=4$, pričom hodnota maxima v týchto bodoch je rovná $1$. Minimum funkcie $f$ na intervale $\langle 2, 4 \rangle$ sa nadobúda v bode $c=3$ a hodnota tohto minima je rovná $0$.
#
# Uvedomme si dôležitosť oboch predpokladov Vety 7 - spojitosť funkcie a uzavretosť intervalu. Ak by sme uvažovali napr. funkciu $\dfrac{1}{x}$, táto je spojitá na otvorenom intervale $(0,1)$ ale nie je na ňom ohraničená! <font color=orange> Uveďte príklad  funkcie takej, ktorá je definovaná na uzavretom intervale, no nie je na ňom spojitá a tým pádom ani ohraničená. </font>
#
# ---

# %% [markdown]
# Ďalšia **veta (Bolzanova) pojednáva o tom, že ak máme spojitú funkciu $f$ na uzavretom intervale $\langle a,b \rangle$ a funkčné hodnoty v krajných bodoch intervalu majú rôzne znamienka t.j. $f(a)\cdot f(b)<0$, potom musí graf funkcie $f$ pretínať os $x$ na intervale $\langle a,b \rangle$**. Inými slovami, existuje $c \in \langle a,b \rangle$ také, že platí $f(c)=0$, tzn. $c$ je nulový bod funkcie $f$ na intervale $\langle a,b \rangle$.

# %% [markdown]
# ---
#
# ### <font color=green> Veta 8 (Bolzano) </font>
#
# Nech funkcia $f$ je definovaná a spojitá na intervale $\langle a,b \rangle$ a nech $\mbox{sgn}(f(a)) \neq \mbox{sgn}(f(b))$. Potom existuje $ \xi \in ( a,b )$ také, že $ f(\xi) = 0$.
#
# ---

# %% [markdown]
# ---
#
# #### <font color=blue> Príklad 9 </font>
#
# Nech $f(x)=\sin x$ a nech $\langle a, b \rangle = \langle -\pi/2, \pi/2 \rangle$. Zrejme $f(x)=\sin x$ je spojitá funkcia na $\mathbb{R}$ a teda aj na intervale $\langle -\pi/2, \pi/2 \rangle$. Z grafu tiež vidieť, že $\mathrm{sgn}(f(-\pi/2))\neq\mathrm{sgn}(f(\pi/2))$ lebo $f(-\pi/2)<0$ a $f(\pi/2)>0$. Podľa Bolzanovej vety existuje $\xi \in \left(-\pi/2,\pi/2\right)$ také, že $f(\xi)=0$. V našom prípade je $\xi=0$.

# %%
x = var('x') 
kwds = {'fontsize':10} 
plot(sin(x), (x, -4, 4), axes_labels=['$x$', '$y$'], axes_labels_size = 1) + line2d([(-pi/2+0.08,0),(pi/2-0.08,0)], color = 'green', thickness=3) + circle((-pi/2,0), 0.05, color = 'green', fill=True) + circle((pi/2,0), 0.05, color = 'green',fill=True) + circle((0,0), 0.05, color = 'red',fill=True) + circle((pi/2,1), 0.05, color = 'orange',fill=True) + circle((-pi/2,-1), 0.05, color = 'orange',fill=True) + line2d([(-pi/2,-1.4),(-pi/2,1.4)], color = 'green', linestyle='dashed') + line2d([(pi/2,-1.4),(pi/2,1.4)], color = 'green', linestyle='dashed') + text(r"$f(x)=\sin\,x$", (2.4, 1.2), color='blue',**kwds) + text(r"$f(0)$", (0.2, -0.2), color='red',**kwds) + text(r"$f(\pi/2)$", (pi/2-0.4, 1.2), color='orange',**kwds) + text(r"$f(-\pi/2)$", (-pi/2-0.5, -1.2), color='orange',**kwds)
# Out:
# Graphics object consisting of 13 graphics primitives

# %% [markdown]
# ---

# %% [markdown]
# Bolzanova veta je základom tzv.  **_metódy polenia intervalov_** (metóda bisekcie), ktorá sa využíva pre numerické (približné) riešenie rovnice $f(x) = 0$ s  požadovanou presnosťou (resp. chybou resp. toleranciou).
#
# **VSTUP:**
# - funkcia $f$ spojitá na množine $J$;
# - interval $I = \langle a,b \rangle \subseteq J$ taký, že $\mathrm{sgn}(f(a)) \neq \mathrm{sgn}(f(b))$;
# - presnosť $\varepsilon$.
#
#
# **VÝSTUP:**
# - približné riešenie $x^*$ (s presnosťou $\varepsilon$) rovnice $f(x) = 0$
#
# **POSTUP:**
# - $k:=0,\,I_k:= I,\, a_k := a,\, b_k := b$;
# - pokiaľ $|a_k - b_k| > 2\varepsilon$, opakuj:
#     - $c_k:=\dfrac{a_k + b_k}{2}$;
#     - ak $\mathrm{sgn}(f(a_k)) \neq \mathrm{sgn}(f(c_k))$ tak $a_{k+1}:=a_k, b_{k+1}:= c_k$ inak $a_{k+1} := c_k,b_{k+1}:=b_k$;
#     - $k:= k+1$;
#
# - $x^* := c_k$.

# %% [markdown]
# ---
#
# #### Poznámka 3
#
# Numericky riešiť rovnicu $f(x)=0$ znamená s vopred zvolenou presnosťou ($\varepsilon$) nájsť približné hodnoty koreňov danej rovnice. Inými slovami, hľadáme nulové body funkcie $f$ t.j. hľadáme také $x$, pre ktoré $f(x)=0$ resp. $f(x)\approx0$.
#
# ---

# %% [markdown]
# ---
#
# #### <font color=blue> Príklad 10 </font>
#
# Metódou bisekcie nájdite reálny koreň rovnice $x^3-x-1=0$ s presnosťou $0.005$.
#
# <ins> Riešenie: <ins/>
#
# Položme $f(x)=x^3-x-1$ a $\varepsilon=0.0005$. Najprv odhadneme korene graficky. Z grafov nižšie je vidieť, že hľadaný koreň $x^*$ rovnice leží v intervale $(1,1.5)$. Modrou farbou je graf priamo funkcie $f(x)=x^3-x-1$. Rovnicu $x^3-x-1=0$ si môžeme prepísať do ekvivalentného tvaru $x^3=x+1$ a pozerať sa na to ako na rovnosť funkcií $f_1(x)=x^3$ a $f_2(x)=x+1$ t.j. $f_1(x)=f_2(x)$ a hľadať také $x^*$, v ktorom sa ich funkčné hodnoty rovnajú. Na obrázku vpravo sú znázornené práve funkcie $f_1$, $f_2$ a $x$-ová súradnica bodu, kde sa pretínajú ich grafy je vlastne hľadaný koreň $x^*$. Sú to len dva pohľady na to isté. Pod grafmi je riešenie metódou poltenia intervalov pomocou Sage. Tu ešte uvádzame prehľadnú tabuľku jednotlivých krokov riešenia, kde $k$ je číslo kroku (iterácie), $a_k$, $b_k$ sú koncové body intervalu v $k$-tom kroku, $c_k$ je príslušný stred intervalu a stĺpec $f(a_k)f(c_k)$ obsahuje znamienka súčinov funkčných hodnôt v bodoch $a_k$, $c_k$. V kroku číslo $6$ t.j. pre $k=6$ platí $(1.3282 − 1.3204) < 2 \cdot 0.005$ a $f(1.3282)f(1.3204) < 0$, môžeme aproximovať koreň $x^*$ pomocou $\tilde{x} = (1.3204 + 1.3282)/2 = 1.3243$.
#
# <style type="text/css">
# .tg  {border-collapse:collapse;border-spacing:0;}
# .tg td{border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;
#   overflow:hidden;padding:10px 5px;word-break:normal;}
# .tg th{border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;
#   font-weight:normal;overflow:hidden;padding:10px 5px;word-break:normal;}
# .tg .tg-baqh{text-align:center;vertical-align:top}
# </style>
# <table class="tg">
# <thead>
#   <tr>
#     <th class="tg-baqh">$k$</th>
#     <th class="tg-baqh">$a_k$</th>
#     <th class="tg-baqh">$b_k$</th>
#     <th class="tg-baqh">$c_k$</th>
#     <th class="tg-baqh">$f(a_k)f(c_k)$</th>
#   </tr>
# </thead>
# <tbody>
#   <tr>
#     <td class="tg-baqh">$0$</td>
#     <td class="tg-baqh">$1$</td>
#     <td class="tg-baqh">$1.5$</td>
#     <td class="tg-baqh">$1.25$</td>
#     <td class="tg-baqh">$+$</td>
#   </tr>
#   <tr>
#     <td class="tg-baqh">$1$</td>
#     <td class="tg-baqh">$1.25$</td>
#     <td class="tg-baqh">$1.5$</td>
#     <td class="tg-baqh">$1.375$</td>
#     <td class="tg-baqh">$-$</td>
#   </tr>
#   <tr>
#     <td class="tg-baqh">$2$</td>
#     <td class="tg-baqh">$1.25$</td>
#     <td class="tg-baqh">$1.375$</td>
#     <td class="tg-baqh">$1.3125$</td>
#     <td class="tg-baqh">$+$</td>
#   </tr>
#   <tr>
#     <td class="tg-baqh">$3$</td>
#     <td class="tg-baqh">$1.3125$</td>
#     <td class="tg-baqh">$1.375$</td>
#     <td class="tg-baqh">$1.3438$</td>
#     <td class="tg-baqh">$-$</td>
#   </tr>
#   <tr>
#     <td class="tg-baqh">$4$</td>
#     <td class="tg-baqh">$1.3125$</td>
#     <td class="tg-baqh">$1.3438$</td>
#     <td class="tg-baqh">$1.3282$</td>
#     <td class="tg-baqh">$-$</td>
#   </tr>
#   <tr>
#     <td class="tg-baqh">$5$</td>
#     <td class="tg-baqh">$1.3125$</td>
#     <td class="tg-baqh">$1.3282$</td>
#     <td class="tg-baqh">$1.3204$</td>
#     <td class="tg-baqh">$+$</td>
#   </tr>
#   <tr>
#     <td class="tg-baqh">$6$</td>
#     <td class="tg-baqh">$1.3204$</td>
#     <td class="tg-baqh">$1.3282$</td>
#     <td class="tg-baqh"></td>
#     <td class="tg-baqh"></td>
#   </tr>
# </tbody>
# </table>

# %%
x = var('x') 
kwds = {'fontsize':12} 
p1 = plot(x^3-x-1, (x, -1.5, 2), axes_labels=['$x$', '$y$'], axes_labels_size = 1) + point((1.32,0), color = 'green', size=30) + text(r"$f(x)=x^3-x-1=0$", (1.2, -2), color='blue',**kwds) + text(r"$x^{*}$", (1.25, 0.3), color='green',**kwds)
p2 = plot(x^3, (x, -1.5, 2), axes_labels=['$x$', '$y$'], axes_labels_size = 1, color='red') + plot(x+1, (x, -1.5, 3), axes_labels=['$x$', '$y$'], axes_labels_size = 1,color='orange') + line2d([(1.32,0),(1.32,2.2)], color = 'green', linestyle='dashed') + point((1.32,0), color = 'green', size=30) + text(r"$f_1(x)=x^3$", (2.5, 5.2), color='red',**kwds) + text(r"$f_2(x)=x+1$", (2.5, 2), color='orange',**kwds) + text(r"$x^{*}$", (1.32, -0.5), color='green',**kwds)
G = graphics_array([p1,p2])
# G.show(figsize=[8, 3]) 
show(G)
# Out:
# Graphics Array of size 1 x 2

# %%
# k = 0
f(x) = x^3-x-1 
epsilon = 0.005
a0 = 1
b0 = 1.5 
c0 = (a0+b0)/2
print('a0 = ', a0) 
print('b0 = ', b0)
print('c0 =', c0) 
print('f(a0)*f(c0) =', f(a0)*f(c0))
print('f(b0)*f(c0) =', f(b0)*f(c0))
print('test presnosti:', abs(a0-b0) < 2*epsilon)
# Out:
# a0 =  1
# b0 =  1.50000000000000
# c0 = 1.25000000000000
# f(a0)*f(c0) = 0.296875000000000
# f(b0)*f(c0) = -0.259765625000000
# test presnosti: False

# %%
# k = 1
a1 = c0
b1 = b0 
c1 = (a1+b1)/2
print('a1 = ', a1)
print('b1 = ', b1)
print('c1 =', c1) 
print('f(a1)*f(c1) =', f(a1)*f(c1))
print('f(b1)*f(c1) =', f(b1)*f(c1)) 
print('test presnosti:', abs(a1-b1) < 2*epsilon)
# Out:
# a1 =  1.25000000000000
# b1 =  1.50000000000000
# c1 = 1.37500000000000
# f(a1)*f(c1) = -0.0666809082031250
# f(b1)*f(c1) = 0.196533203125000
# test presnosti: False

# %%
# k = 2
a2 = a1
b2 = c1 
c2 = (a2+b2)/2
print('a2 = ', a2) 
print('b2 = ', b2)
print('c2 =', c2)
print('f(a2)*f(c2) =', f(a2)*f(c2))
print('f(b2)*f(c2) =', f(b2)*f(c2)) 
print('test presnosti:', abs(a2-b2) < 2*epsilon)
# Out:
# a2 =  1.25000000000000
# b2 =  1.37500000000000
# c2 = 1.31250000000000
# f(a2)*f(c2) = 0.0152931213378906
# f(b2)*f(c2) = -0.0115704536437988
# test presnosti: False

# %%
# k = 3
a3 = c2
b3 = b2 
c3 = (a3+b3)/2
print('a3 = ', a3) 
print('b3 = ', b3)
print('c3 =', c3)
print('f(a3)*f(c3) =', f(a3)*f(c3))
print('f(b3)*f(c3) =', f(b3)*f(c3)) 
print('test presnosti:', abs(a3-b3) < 2*epsilon)
# Out:
# a3 =  1.31250000000000
# b3 =  1.37500000000000
# c3 = 1.34375000000000
# f(a3)*f(c3) = -0.00425560027360916
# f(b3)*f(c3) = 0.0185552239418030
# test presnosti: False

# %%
# k = 4
a4 = a3
b4 = c3 
c4 = (a4+b4)/2
print('a4 = ', a4) 
print('b4 = ', b4)
print('c4 =', c4)
print('f(a4)*f(c4) =', f(a4)*f(c4))
print('f(b4)*f(c4) =', f(b4)*f(c4)) 
print('test presnosti:', abs(a4-b4) < 2*epsilon)
# Out:
# a4 =  1.31250000000000
# b4 =  1.34375000000000
# c4 = 1.32812500000000
# f(a4)*f(c4) = -0.000750861130654812
# f(b4)*f(c4) = 0.00120413571130484
# test presnosti: False

# %%
# k = 5
a5 = a4
b5 = c4 
c5 = (a5+b5)/2
print('a5 = ', a5) 
print('b5 = ', b5)
print('c5 =', c5)
print('f(a5)*f(c5) =', f(a5)*f(c5))
print('f(b5)*f(c5) =', f(b5)*f(c5)) 
print('test presnosti:', abs(a5-b5) < 2*epsilon)
# Out:
# a5 =  1.31250000000000
# b5 =  1.32812500000000
# c5 = 1.32031250000000
# f(a5)*f(c5) = 0.000963852391578257
# f(b5)*f(c5) = -0.000272725117611117
# test presnosti: False

# %%
# k = 6
a6 = c5
b6 = b5 
c6 = (a6+b6)/2
print ('a6 = ', a6) 
print ('b6 = ', b6)
print ('c6 =', c6)
print ('f(a6)*f(c6) =', f(a6)*f(c6))
print ('f(b6)*f(c6) =', f(b6)*f(c6)) 
print ('test presnosti:', abs(a6-b6) < 2*epsilon)
# Out:
# a6 =  1.32031250000000
# b6 =  1.32812500000000
# c6 = 1.32421875000000
# f(a6)*f(c6) = 0.0000398151638307809
# f(b6)*f(c6) = -0.0000310168436499225
# test presnosti: True

# %%
# podmienka resp. poziadavka na presnost je uz splnena, preto algoritmus konci a hladany koren x* mozeme aproximovat nasledovne:
print('aproximacia korena x* s presnostou epsilon = 0.005 je', round(c6,4))
# Out:
# aproximacia korena x* s presnostou epsilon = 0.005 je 1.3242

# %% [markdown]
# ---

# %% [markdown]
# <font color=orange> Skúste si pomocou nasledujúceho interaktívneho kódu vyriešiť Príklad 10 napr. s presnosťou $\varepsilon=0.001$. Čo sa bude diať s počtom intervalov (resp. iterácií), keď budete zvyšovať presnosť $\varepsilon$ ? </font>
#
# <ins>Vstupy</ins>: $f$ - funkcia, ktorej nulový bod hľadáme resp. ľavá strana rovnice $f(x)=0$; koncové body intervalu $(a,b)$,  v ktorom hľadáme približnú hodnotu koreňa rovnice (resp. nulového bodu funkcie $f$); eps - presnosť $\varepsilon$. <br/>
# <ins>Výstupy</ins>: eps - presnosť;  $c$ - približná hodnota koreňa; $f(c)$ - funkčná hodnota v nájdenom približnom riešení rovnice (mala by byť blízka nule); iterations - počet krokov (iterácií) potrebných k nájdeniu približného riešenia s danou presnosťou; grafický výstup v podobe znázornených intervalov nájdených v jednotlivých krokoch riešenia.

# %%
# created by William Stein 

def bisect_method(f, a, b, eps):
    try:
        f = f._fast_float_(f.variables()[0])
    except AttributeError:
        pass
    intervals = [(a,b)]
    two = float(2); eps = float(eps)
    while True:
        c = (a+b)/two
        fa = f(a); fb = f(b); fc = f(c)
        if abs(fc) < eps: return c, intervals
        if fa*fc < 0:
            a, b = a, c
        elif fc*fb < 0:
            a, b = c, b
        else:
            raise ValueError("f must have a sign change in the interval (%s,%s)"%(a,b))
        intervals.append((a,b))
pretty_print(html("<h1>Double Precision Root Finding Using Bisection</h1>"))
@interact
def _(f = cos(x) - x, a = float(0), b = float(1), eps=(-3,(-16, -1))):
     eps = 10^eps
     print("eps = %s" % float(eps))
     try:
         c, intervals = bisect_method(f, a, b, eps)
     except ValueError:
         print("f must have opposite sign at the endpoints of the interval")
         show(plot(f, a, b, color='red'), xmin=a, xmax=b)
     else:
         print("c =", c)
         print("f(c) = %r" % f(x=c))
         print("iterations =", len(intervals))
         P = plot(f, a, b, color='red')
         h = (P.ymax() - P.ymin())/ (1.5*len(intervals))
         L = sum(line([(c,h*i), (d,h*i)]) for i, (c,d) in enumerate(intervals) )
         L += sum(line([(c,h*i-h/4), (c,h*i+h/4)]) for i, (c,d) in enumerate(intervals) )
         L += sum(line([(d,h*i-h/4), (d,h*i+h/4)]) for i, (c,d) in enumerate(intervals) )
         show(P + L, xmin=a, xmax=b)
# Out:
# <h1>Double Precision Root Finding Using Bisection</h1>
# Interactive function <function _ at 0x6fda94d9f28> with 4 widgets
#   f: EvalText(value='-x + cos(x)', descripti…

# %% [markdown]
# <font color=purple> EXTRA: Naprogramujte v Sage funkciu, ktorá bude pomocou metódy polenia intervalov numericky riešiť rovnicu zadanú na vstupe so zadanou presnosťou. Otestujte správnosť Vašej funkcie na niekoľkých vstupoch. V prípade správneho vypracovania tejto úlohy a zaslania okomentovaného kódu môžete získať dva bonusové body. </font>

# %% [markdown]
# Veta 9 hovorí, že **funkcia, ktorá je spojitá na intervale $\langle a,b \rangle$ musí nadobúdať všetky hodnoty, ktoré sú medzi hodnotami $f(a)$ a $f(b)$**.

# %% [markdown]
# ---
#
# ### <font color=green> Veta 9 (Darboux) </font>
#
# Nech funkcia $f$ je definovaná a spojitá na intervale $\langle a,b \rangle$ a nech $f(a) \neq f(b)$. Nech $d$ je ľubovoľné číslo také, že $f(a) < d < f(b)$ resp. $f(b) < d < f(a)$. Potom existuje $ c \in (a,b))$ také, že $f(c) = d$.
#
# ---

# %% [markdown]
# ---
#
# ### <font color=green> Veta 10 </font>
#
# Nech funkcia $f$ je definovaná a spojitá na intervale (ľubovoľného typu) $I$. Potom obraz intervalu $I$ pri funkcii $f$ je buď jednobodová množina alebo interval.
#
# ---

# %% [markdown]
# ---
#
# #### <font color=blue> Príklad 11 </font>
#
# Uvažujme napr. funkciu $f(x)=\sin x$ na intervale $\langle 0, 2\pi )$ (vykreslite si graf). Na tomto intervale je uvažovaná funkcia spojitá a nadobúda všetky hodnoty od $-1$ po $1$, t.j. $\langle -1, 1 \rangle$. Symbolicky by sme to mohli vyjadriť takto: "$f\left(\langle 0, 2\pi )\right)=\langle -1, 1 \rangle$", to značí, že obrazom intervalu $\langle 0, 2\pi )$ pri funkcii $f$ je interval $\langle -1, 1 \rangle$.
#
# ---

# %% [markdown]
# ---
#
# ### <font color=green> Veta 11 </font>
#
# Ak $f$ je rýdzomonotónna a spojitá funkcia na intervale $I$ a $J$ je obraz intervalu $I$ pri funkcii $f$ (t.j. "$J,=f(I)$"), tak inverzná funkcia $f^{-1}$ je spojitá na intervale $J$.
#
# ---

# %% [markdown]
# ---
#
# #### <font color=blue> Príklad 12 </font>
#
# Uvažujme napr. funkciu $f(x)=\sin x$ na intervale $\langle -\pi/2, \pi/2 )$ (vykreslite si graf). Na tomto intervale je uvažovaná funkcia rýdzomonotónna a spojitá. Obrazom intervalu $I=\langle -\pi/2, \pi/2 )$ pri funkcii $f$ je interval $J=\langle -1, 1 \rangle$. Na $I=\langle -\pi/2, \pi/2 )$ existuje k $f(x)=\sin x$ inverzná funkcia $f^{-1}(x)=\arcsin x$ (vykreslite graf). Funkcia $f^{-1}(x)=\arcsin x$ je podľa Vety 11 spojitá na $J=\langle -1, 1 \rangle$.
#
# ---

# %% [markdown]
# ---
#
# ### <font color=green> Veta 12 </font>
#
# Nech funkcia $f$ je definovaná a monotónna na intervale $I$ a nech obor hodnôt funkcie $f$ na intervale $I$ je jednoprvková množina alebo interval. Potom funkcia $f$ je spojitá na intervale $I$.
#
# ---

# %% [markdown]
# <font color=orange> Uveďte príklad funkcie pre ilustráciu tvrdenia vo Vete 12. Nezabudnite overiť/zdôvodniť, že Vami zvolená funkcia spĺňa predpoklady, ktoré sú vo Vete 12, a že pre Vami zvolenú funkciu platí to, čo tvrdí Veta 12. </font>

# %% [markdown]
# ***
# <a id=zdroje></a>
#  # <font color=brown> Použité zdroje</font>

# %% [markdown]
# * Boelkins M., Austin D., Schlicker S. (2018). Active Calculus. 978-1085940856.
#
#
# * Goldstein L. J. et al. (2017). Calculus & Its Applications. Pearson Education.
#
#
# * Hartman G. et al. (2018). APEX Calculus. 978-1514225158.
#
#
# * Hallet D. H. et al. (2017). Calculus: Single Variable. Wiley.
#
#
# * Hallet D. H. (2014). Applied Calculus. John Wiley & Sons.
#
#
# * [Prednáška](https://umv.science.upjs.sk/madaras/MZIa/MZIa2011_9.pdf) prof. Madaras.

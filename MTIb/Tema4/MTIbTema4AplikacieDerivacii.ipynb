# %% [markdown]
# **Author:** Andrej Gajdoš  <br> *[Faculty of Science](https://www.upjs.sk/en/faculty-of-science/?prefferedLang=EN), P. J. Šafárik University in Košice, Slovakia* <br> email: [andrej.gajdos@upjs.sk](mailto:andrej.gajdos@upjs.sk)
# ***
# **_Tento materiál vznikol za podpory grantu VVGS-2021-1758._**
# ***
#
# **<font size=6 color=gold> MTIb: Téma 4 - Aplikácie derivácií funkcií </font>**

# %% [markdown]
# ***
# <a id=lhospital></a>
#  # <font color=brown> Výpočet špecifických limít funkcií </font>

# %% [markdown]
# Ak existuje $\lim\limits_{x\to x_0}f(x)$, $\lim\limits_{x\to x_0}g(x)$ a $\lim\limits_{x\to 0}g(x)\ne0$, tak existuje aj limita podielu  $\dfrac{f(x)}{g(x)}$ rovná podielu obidvoch limít (téma 1, Veta 4, časť e) ). V prípade, že $\lim\limits_{x\to x_0}f(x)$ existuje a $\lim\limits_{x\to x_0}g(x) = \pm \infty$, limita podielu $\dfrac{f(x)}{g(x)}$ je rovná $0$; v prípade, že $\lim\limits_{x\to x_0}f(x) = \pm \infty$ a $\lim\limits_{x\to x_0}g(x)$ existuje a je nenulová, limita podielu je (až na znamienko) $\infty$ resp. neexistuje (v zmysle, že existujú len navzájom rôzne nevlastné jednostranné limity).
#
# Prípady, kedy o limite podielu $\dfrac{f(x)}{g(x)}$ nemožno rozhodnúť podľa uvedených tvrdení, sú prípady, keď $\lim\limits_{x \to x_0} f(x) = \lim\limits_{x \to x_0} g(x) = 0$ alebo keď $\lim\limits_{x \to x_0} f(x) = \lim\limits_{x \to x_0} g(x) = \pm \infty$ (tzv. limity typu "$\frac{0}{0}$" alebo typu "$\frac{\infty}{\infty}$"). Uvedené prípady rieši za určitých predpokladov nasledujúca veta.

# %% [markdown]
# ---
#
# ### <font color=green> Veta 1 (L'Hospitalovo pravidlo) </font>
#
# Nech $f$, $g$ sú funkcie, $\lim\limits_{x\to x_0}f(x)=\lim\limits_{x\to x_0}g(x)=0$ alebo $\lim\limits_{x\to x_0}f(x)=\lim\limits_{x\to x_0}g(x)=\pm \infty$. Nech existuje $\lim\limits_{x\to x_0}\dfrac{f'(x)}{g'(x)}$ (vlastná alebo nevlastná). Potom existuje aj $\lim\limits_{x\to x_0}\dfrac{f(x)}{g(x)}$ a tieto dve limity sú rovnaké.
#
# ---

# %% [markdown]
# ---
#
# #### Poznámka 1
#
# * Ak limita $\lim\limits_{x\to x_0}\dfrac{f'(x)}{g'(x)}$ neexistuje, tak o limite $\lim\limits_{x\to x_0}\dfrac{f(x)}{g(x)}$ nemožno nič tvrdiť! (na základe Vety 1)
#
#
# * Pri L'Hospitalovom pravidle  výraz za znakom limity **nederivujeme ako podiel**, ale čitateľa a menovateľa zvlášť!
#
#
# * L'Hospitalovo pravidlo je možné aplikovať aj v prípade jednostranných limít.
#
# ---

# %% [markdown]
# ---
#
# #### <font color=blue> Príklad 1 </font>
#
# Vypočítajte $\lim\limits_{x\to 0}\dfrac{1-\cos x}{x^2}$.
#
# <ins> Riešenie: </ins>
#
# Keďže $\lim\limits_{x\to0}(1-\cos x)=0$, $\lim\limits_{x\to0}x^2=0$, môžeme použiť L'Hospitalovo pravidlo. Dostávame tak
#
# $$\lim\limits_{x\to 0}\dfrac{1-\cos x}{x^2} = \lim\limits_{x\to0}\dfrac{(1-\cos x)'}{(x^2)'}=\lim\limits_{x\to0}\dfrac{\sin x}{2x}=\frac12\lim\limits_{x\to0}\dfrac{\sin x}x=\frac12\cdot1=\frac12.$$
#
# ---

# %% [markdown]
# ---
#
# #### <font color=blue> Príklad 2 </font>
#
# Vypočítajte $\lim\limits_{x\to\infty}\dfrac x{e^x}$.
#
# <ins> Riešenie: </ins>
#
# Keďže $\lim\limits_{x\to \infty}x=\infty$, $\lim\limits_{x\to\infty}e^x = \infty$, môžeme použiť L'Hospitalovo pravidlo. Dostávame tak
#
# $$\lim\limits_{x\to\infty}\dfrac x{e^x}=\lim\limits_{x\to\infty}\dfrac{(x)'}{(e^x)'}=\lim\limits_{x\to\infty}\dfrac1{e^x}=0.$$
#
# ---

# %% [markdown]
# ---
#
# #### Poznámka 2
#
# V niektorých prípadoch L'Hospitalovo pravidlo nemusí viesť k výsledku: jeho opakovaným použitím pri výpočte $\lim\limits_{x\to\infty}\dfrac{\sqrt{x^2-1}}x$ dostávame
#
# $$
# 	\lim_{x\to\infty}\frac{\sqrt{x^2-1}}x = \lim_{x\to\infty}\frac{\frac{2x}{2\sqrt{x^2-1}}}{1} = \lim_{x\to\infty}\frac {x}{\sqrt{x^2-1}}=$$ $$ \lim_{x\to\infty}\frac{1}{\frac{2x}{2\sqrt{x^2-1}}} =\lim_{x\to\infty}\frac{\sqrt{x^2-1}}x=\dots\,.
# $$
#
# Opakovaným použitím L'Hospitalovo pravidla dostávame rovnakú limitu ako na začiatku a výpočet sa "zacyklí".
#
# Ľahko ale vidieť, že
# $$
# 	\lim_{x\to\infty}\frac{\sqrt{x^2-1}}x= \lim\limits_{x \to \infty} \sqrt{\frac{x^2 - 1}{x^2}} = \lim\limits_{x \to \infty} \sqrt{\frac{x^2}{x^2}-\frac{1}{x^2}}  = \lim_{x\to\infty}\sqrt{1-\frac1{x^2}}=\sqrt1=1\,.
# $$
#
# ---

# %% [markdown]
# <font color=orange> Prečo platí $\lim_{x\to\infty}\sqrt{1-\frac1{x^2}}=\sqrt1$ ? Je to časť výpočtu v Poznámke 2. Pomôžte si tvrdeniami o limitách z predchádzajúcich tém. </font>

# %% [markdown]
# **L'Hospitalovo pravidlo možno niekedy využiť aj pri výpočte limít, ktoré nie sú typu "$\frac{0}{0}$" resp. "$\frac{\infty}{\infty}$":**
#
# * $\lim\limits_{x \to x_0} f(x)\cdot g(x)$ je typu "$0\cdot\infty$", t.j. $\lim\limits_{x \to x_0} f(x) = 0$ a $ \lim\limits_{x \to x_0} g(x) = \pm\infty$, tak možno využiť úpravu
#
#     $$
# 	f(x)\cdot g(x) = \dfrac{f(x)}{\frac{1}{g(x)}} = \dfrac{g(x)}{\frac{1}{f(x)}}
# 	$$
#
#     čím sa výpočet transformuje na výpočet limity typu "$\frac{0}{0}$" alebo typu "$\frac{\infty}{\infty}$".
#
#
# * ak $\lim\limits_{x \to x_0} (f(x) - g(x))$ je typu"$\infty - \infty$", t.j. $\lim\limits_{x \to x_0} f(x) =$ $ \lim\limits_{x \to x_0} g(x) = +\infty$, tak možno využiť úpravu
#
#     $$
# 	f(x) - g(x) = \dfrac{\frac{1}{g(x)} - \frac{1}{f(x)}}{\frac{1}{f(x)g(x)}}
# 	$$
#
#     čím sa výpočet transformuje na výpočet limity typu "$\frac{0}{0}$".
#
#
# * ak $\lim\limits_{x \to x_0} f(x)^{g(x)}$ je typu "$0^0$", "$\infty^0$" alebo "$1^\infty$", tak možno využiť úpravu
#
#     $$
# 	f(x)^{g(x)} = e^{\ln(f(x)^{g(x)})} = e^{g(x)\ln f(x)}
# 	$$
#
#     $$ \lim\limits_{x \to x_0} f(x)^{g(x)} = e^{\lim\limits_{x \to x_0}g(x)\ln f(x)}
# 	$$
#
#     čím sa výpočet transformuje na výpočet limity typu "$0\cdot \infty$" v exponente a tu uplatníme prvý bod tohto odseku.

# %% [markdown]
# ---
#
# #### <font color=blue> Príklad 3 </font>
#
# Vypočítajte limitu $\lim\limits_{x\to0^+}x^x$.
#
# <ins> Riešenie: </ins>
#
# Upravíme výraz $x^x$ (využitím vzťahu $x^x = e^{\ln\left ( x^x \right )}$) a použijeme L'Hospitalovo pravidlo:
#
# $$\lim\limits_{x\to0^+}x^x=\lim\limits_{x\to0^+}e^{x\ln x}=e^{\lim\limits_{x\to0^+}x\ln x}=e^{\lim\limits_{x\to0^+}\frac{\ln x}{\frac1x}}=e^{\lim\limits_{x\to0^+}\frac{\frac1x}{-\frac1{x^2}}}=e^{\lim\limits_{x\to0^+}(-x)}=e^0=1.$$
#
# ---

# %% [markdown]
# <font color=orange> Prečo platí vzťah $\lim\limits_{x\to0^+}e^{x\ln x}=e^{\lim\limits_{x\to0^+}x\ln x}$, ktorý sa využil v Príklade 3? Pomôžte si tvrdeniami o limitách a spojitosti z predchádzajúcich tém. </font>

# %% [markdown]
# ***
# <a id=diferencial></a>
#  # <font color=brown> Aproximácia hodnôt funkcie </font>

# %% [markdown]
# Spomeňme si, že derivácia funkcie $f$ môže poslúžiť na nájdenie smernice dotyčnice ku grafu funkcie $f$. V bode $x=x_0$ má dotyčnica $l$ rovnicu $l:\ y=f(x_0)+f'(x_0)\cdot(x-x_0)$. Pomocou dotyčnice je možné aproximovať hodnoty $f(x)$ pre $x$ blízko $x_0$.
#
# Predpokladajme, že chceme pomocou (hodnoty) dotyčnice aproximovať (približne vyčísliť) hodnotu $\sin\,(1.1)$. Potrebujeme k tomu dotyčnicu k funkcii $f(x)=\sin\,x$ napr. v bode $x_0=\frac{\pi}{3}\approx 1.05$. Podstatné je aby bod, v ktorom dotyčnicu zostrojíme bol blízko bodu $1.1$. Zrejme $1.05$ je blízko k $1.1$. Vieme, že $\sin\,(\pi/3)=\sqrt{3}/2\approx 0.866$ a $\left(\sin\,x\right)'=\cos\,x$, pričom $\cos\,(\pi/3)=1/2$. Preto dotyčnica k $f(x)=\sin\,x$ v bode $x_0=\pi/3$ je
#
# $$l:y=\ \frac{1}{2}\left(x-\frac{\pi}{3}\right)+0.866 \qquad \text{ resp. } \qquad l(x)=\frac{1}{2}\left(x-\frac{\pi}{3}\right)+0.866.$$
#
# ![diferencial_dotycnica.png](attachment:diferencial_dotycnica.png)
# $$\text{Zdroj: Hartman (2018).}$$
#
# Na obrázku (a) je znázornený graf funkcie $f(x)=\sin\,x$ (modrá farba) spolu s dotyčnicou v bode $x_0=\pi/3$ (červená farba). Malý obdĺžnik znázorňuje oblasť, ktorá je zväčšená (priblížená) na obrázku (b). Práve na obrázku (b) môžeme vidieť ako je hodnota $\sin\,(1.1)$ aproximovaná pomocou hodnoty dotyčnice vyčíslenej v bode $1.1$ t.j. $l(1.1)$. Obidva obrázky ukazujú, ako blízke sú tieto hodnoty resp. aká dobrá je to aproximácia (červená priamka je blízko modrej krivky v bode $1.1$). Aproximácia hodnoty $\sin\,(1.1)$ pomocou hodnoty dotyčnice $l(1.1)$ vyzerá nasledovne:
#
# $$l(1.1)=\frac{1}{2}(1.1-\pi/3)+0.866=\frac{1}{2}(0.053)+0.866=0.8925.$$
#
# Len pre porovnanie $\sin\,(1.1)=0.8912\ldots$ .
#
# Teraz sa pokúsime ilustrovaný koncept zovšeobecniť. Pre danú funkciu $f(x)$ a bod $x_0$ je dotyčnica k $f$ v bode $x_0$ daná predpisom $l(x)=f'(x_0)(x-x_0)+f(x_0)$. Zrejme $f(x_0)=l(x_0)$. Nech $\Delta x_0$ je malé číslo vyjadrujúce malú zmenu v hodnote $x_0$ tzn. $x_0+\Delta x_0 = x$ resp. $\Delta x_0 = x - x_0$ . Keďže $x$ je blízko k $x_0$ a dotyčnica v $x_0$ dobre aproximuje hodnoty $f(x)$ pre $x$ blízke $x_0$, tak môžeme tvrdiť že $f(x)$ je porovnateľné (blízke) s $l(x_0)$, čo označíme
#
# $$f(x) \approx l(x_0).$$
#
# Keď sa hodnota $x_0$ zmení na $x$, potom sa hodnota $f$ zmení z $f(x_0)$ na $f(x)$ t.j. hodnota $f$ sa zmení o $\Delta f(x_0)=f(x)-f(x_0)$. Ak vo vzťahu pre $\Delta f(x_0)$ nahradíme $f(x)$ aproximáciou pomocou dotyčnice (ako je uvedené vyššie) v bode $x_0$, tak dostávame
#
# $$\Delta f(x_0) = f(x)-f(x_0) \approx l(x_0)-f(x_0)=f'(x_0)\left((x-x_0\right)+f(x_0)-f(x_0)=f'(x_0)\cdot(x-x_0)=f'(x_0)\cdot\Delta x_0.$$
#
# **Kľúčový je posledný výraz resp. približná rovnosť $\Delta f(x_0) \approx f'(x_0)\Delta x_0 = f'(x_0)(x-x_0)$. V jednoduchosti povedané nám to hovorí, že ak sa zmení $x_0$ na $x$ (kde $x$ je blízko $x_0$ a platí $x_0+\Delta x_0=x$), potom hodnota funkcie $f$ sa zmení približne o hodnotu $f'(x_0)(x-x_0)$.** Výraz $f'(x_0)(x-x_0)$ je natoľko dôležitý, že si zaslúži špeciálne pomenovanie a hovorí o tom nasledujúca definícia.

# %% [markdown]
# ---
#
# ### <font color=red> Definícia 1 </font>
#
# Nech funkcia $f$ má v bode $x_0$ deriváciu. Potom výraz $\mbox{d}f(x_0,x) = f'(x_0)(x - x_0)$ sa nazýva **_diferenciál_**  funkcie $f$ v bode $x_0$ pre prírastok $x - x_0$.
#
# ---

# %% [markdown]
# Z geometrického hľadiska, diferenciál funkcie $f$ v bode $x_0$ pre prírastok $x - x_0$ zodpovedá rozdielu funkčnej hodnoty v bode $x$ pre funkciu $y = f'(x_0)(x-x_0) + f(x_0)$ a funkčnej hodnoty $f(x_0)$ (t.j. prírastok lineárnej funkcie vyjadrujúcej rovnicu dotyčnice ku grafu $f$ v bode $[x_0,f(x_0)]$).
#
# ![diferencial.png](attachment:diferencial.png)
# $$\text{Zdroj: Madaras (2019).}$$

# %% [markdown]
# Skúmajme vzťah diferenciálu $\mbox{d}f(x_0,x)$ voči funkčným hodnotám $f(x_0),f(x)$.
# Ak označíme $\tau(x_0,x) = \Delta f(x_0) - \mbox{d}f(x_0,x) = (f(x) - f(x_0)) - \mbox{d}f(x_0,x)$, tak platí
#
# $$\lim\limits_{x \to x_0} \tau(x_0,x) = \lim\limits_{x \to x_0} ((f(x) - f(x_0)) - \mbox{d}f(x_0,x)) = 0 - \lim\limits_{x \to x_0} f'(x_0)(x - x_0) = 0-0 = 0.$$
#
# Z toho  vyplýva, že **pre $x$ dostatočne blízke $x_0$ je možné funkčnú hodnotu $f(x)$ aproximovať výrazom $f(x_0) + f'(x_0)(x - x_0)$** (pričom relatívna chyba $\dfrac{|\Delta f(x_0) - \mbox{d}f(x_0)|}{|f(x_0)|}=\dfrac{|f(x)-(f(x_0) + f'(x_0)(x - x_0))|}{|f(x_0)|}$ aproximácie skutočnej hodnoty $f(x_0)$ závisí len na rozdieli $x - x_0$).

# %% [markdown]
# ---
#
# #### <font color=blue> Príklad 4 </font>
#
# Vypočítajte približne $\sqrt{4,02}$.
#
# <ins> Riešenie: </ins>
#
# Označme $f:\ y = \sqrt{x},x=4.02,x_0 = 4, \Delta x=h = x-x_0 = 0.02$. Platí $f'(x) = \frac{1}{2\sqrt{x}}$. Na základe horeuvedeného približného vzťahu možno potom písať $f(x_0 + h) \doteq f(x_0) + f'(x_0)\cdot h = $ $\sqrt{4} + \frac{1}{2\sqrt{4}}\cdot (0.02) =$ $ 2 + \frac{1}{4}\cdot (0.02) = 2.005$ (poznamenajme, že presná hodnota je $2.00499376557\dots$).
#
# ---

# %% [markdown]
# ---
#
# #### <font color=blue> Príklad 5 </font>
#
# Vypočítajte približne $\sin 29^\circ$.
#
# <ins> Riešenie: </ins>
#
# Najprv je potrebné premeniť argument $29^\circ$ na oblúkovú mieru (vzhľadom na ktorú je funkcia sínus definovaná; bolo by teda nesprávne vyjadriť $x = 29^\circ = 30^\circ - 1^\circ$ a ďalej v približnom vyjadrení  počítať s $h = 1^\circ$ ako s číslom $1$). Platí $29^\circ = \frac{2\pi}{360}\cdot 29$; označme $x = \frac{2\pi}{360}\cdot 29, x_0 = \frac{2\pi}{360}\cdot 30 = \frac{\pi}{6}, \Delta x = h = x - x_0 = -\frac{\pi}{180}$. Označme ďalej $f:\ y = \sin x$; platí $f'(x) = \cos x$. Potom možno približne počítať $f(x_0 + h) \doteq f(x_0) + f'(x_0)\cdot h = \sin \frac{\pi}{6} + \cos \frac{\pi}{6} \cdot \left ( -\frac{\pi}{180} \right ) = \frac{1}{2} - \frac{\sqrt{3}}{2}\cdot \frac{\pi}{180} = 0.5 - 0.01511499 = 0.48488501\ldots$ (poznamenajme, že presná hodnota je $0.4848096202\dots$, teda výsledok získaný približným výpočtom je platný na štyri desatinné miesta).
#
# ---

# %% [markdown]
# ***
# <a id=monotonnost></a>
#  # <font color=brown> Určovanie monotónnosti funkcie</font>

# %% [markdown]
# ---
#
# ### <font color=red> Definícia 2 </font>
#
# Funkcia $f$ sa nazýva **_rastúca v bode_** $x_0$, ak existuje $\delta>0$ také, že pre všetky $x \in (x_0 - \delta, x_0)$ platí $f(x) < f(x_0)$ a pre všetky $x \in (x_0,x_0+\delta)$ platí $f(x) > f(x_0)$.
#
# Funkcia $f$ sa nazýva **_klesajúca v bode_** $x_0$, ak existuje $\delta>0$ také, že pre všetky $x \in (x_0 - \delta, x_0)$ platí $f(x) > f(x_0)$ a pre všetky $x \in (x_0,x_0+\delta)$ platí $f(x) < f(x_0)$.
#
# ---

# %% [markdown]
# **Definíciu 2 je možné si predstaviť** (viď nasledujúci graf) **na** jednoduchom **príklade funkcie $f(x)=x\cdot\ln x$**. V Definícii 2 položme $x_0=1$ a overíme, že funkcia $f(x)=x\cdot\ln x$ je rastúca v tomto bode v zmysle Definície 2. Vezmime $\delta=0.2$, čím dostaneme ľavé (prstencové) okolie $(x_0-\delta,x_0)=(0.8,1)$ bodu $x_0=1$ a tiež pravé (prstencové) okolie $(x_0,x_0+\delta)=(1,1.2)$ bodu $x_0=1$. Pozrime sa najprv na zvolené ľavé (prstencové) okolie bodu $x_0=1$. Zrejme $\forall x\in(0.8,1)$ platí, že $f(x)<f(x_0)$, konkrétne napr. pre $x=0.9$ máme $f(x)=f(0.9)=−0.0948<0=f(1)=f(x_0)$, čiže $f(0.9)<f(1)$. Teraz preskúmajme zvolené pravé (prstencové) okolie bodu $x_0=1$. Zrejme $\forall x\in(1,1.2)$ platí, že $f(x_0)<f(x)$, konkrétne napr. pre $x=1.15$ máme $f(x_0)=f(1)=0<0.1607=f(1.15)=f(x)$, čiže $f(1)<f(1.15)$. <br/>
# Keď to zhrnieme, tak v ľavom (prstencovom) okolí sú funkčné hodnoty menšie ako $f(x_0)$ resp. $f(1)$ v našom príklade a v pravom (prstencovom) okolí sú funkčné hodnoty väčšie ako $f(x_0)$ resp. $f(1)$ v našom príklade. To podľa Definície 2 znamená, že funkcia $f(x)=x\cdot\ln x$ je rastúca v bode $x_0=1$.

# %%
x = var('x') 
f(x) = x*log(x)
kwds = {'fontsize':11} 
plot(f(x), (x, 0.1, 1.5), axes_labels=['$x$', '$y$'], axes_labels_size = 1, figsize=5) + point([1, 0], size=50, color='red') + text(r"$f(x)=x\cdot \ln(x)$", (1, 0.4), color='blue',**kwds) + line([(0.8,0.6),(0.8,-0.6)], linestyle = 'dashed', color = 'black') + line([(1.2,0.6),(1.2,-0.6)], linestyle = 'dashed', color = 'black')
# Out:
# Graphics object consisting of 5 graphics primitives

# %% [markdown]
# ---
#
# #### <font color=green> Tvrdenie 1 </font>
#
# Ak funkcia $f$ je definovaná na intervale $(a,b)$ a je rastúca (resp. klesajúca) v bode $x$ pre všetky $x \in (a,b)$, tak $f$ je rastúca (resp. klesajúca) na intervale $(a,b)$.
#
# ---

# %% [markdown]
# Tvrdenie 1 v prípade funkcie $f(x)=x\cdot\ln x$ (uvedenej vyššie) znamená, že napr. na intervale $(0.8,1.2)$ je táto funkcia rastúca, lebo je rastúca v každom bode tohto intervalu v zmysle Definície 2.

# %% [markdown]
# ---
#
# #### <font color=blue> Príklad 6 </font>
#
# Odhadnite hodnoty derivácie funkcie $f(x)$ znázornenej na obrázku v bodoch $x_0\in\{-2,-1,0,1,2,3,4,5\}$.
#
# ![sklony_dotycnic_priblizne.png](attachment:sklony_dotycnic_priblizne.png)
# $$\text{Zdroj: Halllet (2017).}$$
#
# <ins> Riešenie: </ins>
#
# Z grafu odhadneme hodnotu derivácie v príslušnom bode tak, že urobíme dotyčnicu v danom bode a pomôžeme si štvorcovou mriežkou aby sme lepšie odhadli sklon dotyčnice. Napr. dotyčnica v bode $-1$ je naznačená čiernou priamkou na obrázku vyššie a má sklon približne rovný hodnote $2$ t.j. $f'(-1) \approx 2$. Všimnime si, že sklon dotyčnice v bode $-2$ je kladný a dosť veľký, naproti tomu sklon dotyčnice v bode $-1$ je tiež kladný ale menší čo do veľkosti (sklon - veľkosť uhla, ktorý zviera dotyčnica s osou $x$ - viď téma 3). V bode $0$ je sklon dotyčnice záporný a v bode $-1$ je ešte viac záporný atď. Niektoré odhady derivácií (resp. sklonov dotyčníc) sú uvedené v tabuľke nižšie. Pozrime sa na tieto hodnoty. Sú zmysluplné? Je derivácia kladná či záporná práve tam, kde by sme to očakávali?
#
# <style type="text/css">
# .tg  {border-collapse:collapse;border-spacing:0;}
# .tg td{border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;
#   overflow:hidden;padding:10px 5px;word-break:normal;}
# .tg th{border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;
#   font-weight:normal;overflow:hidden;padding:10px 5px;word-break:normal;}
# .tg .tg-c3ow{border-color:inherit;text-align:center;vertical-align:top}
# .tg .tg-7btt{border-color:inherit;font-weight:bold;text-align:center;vertical-align:top}
# </style>
# <table class="tg">
# <thead>
#   <tr>
#     <th class="tg-7btt">$x$</th>
#     <th class="tg-c3ow">-2</th>
#     <th class="tg-c3ow">-1</th>
#     <th class="tg-c3ow">0</th>
#     <th class="tg-c3ow">1</th>
#     <th class="tg-c3ow">2</th>
#     <th class="tg-c3ow">3</th>
#     <th class="tg-c3ow">4</th>
#     <th class="tg-c3ow">5</th>
#   </tr>
# </thead>
# <tbody>
#   <tr>
#     <td class="tg-7btt">$f'(x)$</td>
#     <td class="tg-c3ow">6</td>
#     <td class="tg-c3ow">2</td>
#     <td class="tg-c3ow">-1</td>
#     <td class="tg-c3ow">-2</td>
#     <td class="tg-c3ow">-2</td>
#     <td class="tg-c3ow">-1</td>
#     <td class="tg-c3ow">1</td>
#     <td class="tg-c3ow">4</td>
#   </tr>
# </tbody>
# </table>
#
# ---

# %% [markdown]
# ---
#
# #### Poznámka 3
#
# Všimnime si v tabuľke v Príklade 6, že každej hodnote $x$ odpovedá jedna konkrétna hodnota $f'(x)$. Preto derivácia je sama o sebe funkciou premennej $x$.
#
# ---

# %% [markdown]
# ---
#
# #### <font color=blue> Príklad 7 </font>
#
# Načrtnite graf derivácie $f'(x)$ funkcie $f(x)$ z Príkladu 6.
#
# <ins> Riešenie: </ins>
#
# Načrtneme hodnoty derivácií z tabuľky z Príkladu 6 a spojíme ich hladkou krivkou aby sme dostali nejakú aproximáciu funkcie, ktorá reprezentuje deriváciu funkcie znázornenej v Príklade 6. Hodnoty derivácie udávajú sklony dotyčníc ku grafu pôvodnej funkcie a teda vypovedajú aj o správaní sa pôvodnej funkcie - teda či rastie, klesá alebo je konštantná.
#
# ![funkcia_derivacia.png](attachment:funkcia_derivacia.png)
# $$\text{Zdroj: Halllet (2017).}$$
#
# Zamyslime sa nad grafom derivácie (čierna krivka). Tam, kde sú hodnoty $f'$ kladné, funkcia $f$ je rastúca t.j. pre $x<-0.3$ a $x>3.8$. Naproti tomu tam, kde sú hodnoty $f'$ záporné, funkcia $f$ je klesajúca. Všimnime si ešte, že body, v ktorých má $f$ veľký pozitívny sklon (prudko rastie) ako napr. v bode $-2$, graf derivácie je tu vysoko nad osou $x$, keďže hodnota derivácie v tomto bode je veľká. V bodoch, kde je sklon funkcie miernejší (funkcia $f$ rastie pomalšie resp. menej prudko) ako napr. v bode $-1$, tu je graf derivácie $f'$ bližšie k osi $x$ lebo derivácia má menšiu hodnotu.
#
# ---

# %% [markdown]
# **Čo nám teda derivácia funkcie hovorí z vizuálneho hľadiska?**
#
# Tam, kde je $f'$ kladná, dotyčnica k $f$ smeruje nahor. Tam kde je $f'$ záporná, dotyčnica k $f$ smeruje nadol. Ak je $f'=0$ všade, potom dotyčnica je horizontálna priamka (rovnobežná s osou $x$) všade a $f$ je konštantná funkcia. Vidíme teda, že znamienko derivácie $f'$ nám hovorí, či je funkcia $f$ rastúca (vtedy je $f'>0$) alebo klesajúca (vtedy je $f'<0$) alebo konštantná (vtedy $f'=0$).
#
# Naviac veľkosť derivácie (v danom bode) udáva veľkosť miery zmeny funkcie $f$ v danom bode resp. ako rýchlo rastie/klesá funkcia (v danom bode). Ináč povedané, ak $f'$ má veľkú hodnotu (kladnú/zápornú), potom graf funkcie $f$ je strmý (prudko rastie/klesá smerom nahor/nadol). Na druhej strane ak má derivácia $f'$ malú hodnotu tak graf funkcie $f$ je miernejší, nie je veľmi strmý (funkcia $f$ mierne rastie/klesá). V tejto súvislosti sa môžeme dozvedieť o správaní sa funkcie $f$ zo správania sa jej derivácie $f'$. Formálne o tom hovorí Tvrdenie 2.

# %% [markdown]
# ---
#
# #### <font color=green> Tvrdenie 2 </font>
#
# Ak $f'(x_0) > 0$ alebo $f'(x_0) = +\infty$, tak $f$ je rastúca v $x_0$. Ak $f'(x_0) < 0$ alebo $f'(x_0) = -\infty$, tak $f$ je klesajúca v $x_0$.
#
# ---

# %% [markdown]
# ---
#
# #### <font color=green> Tvrdenie 3 </font>
#
# Ak funkcia $f$ je v bode $x_0$ neklesajúca (resp. nerastúca) a $f'(x_0)$ existuje, tak $f'(x_0)\ge0$ (resp. $f'(x_0)\leq 0$).
#
# ---

# %% [markdown]
# ---
#
# #### <font color=green> Dôsledok 1 </font>
#
# Nech $f$ má v $x_0$ deriváciu. Potom $f$ je v bode $x_0$ neklesajúca (resp. nerastúca) práve vtedy, keď $f'(x_0)\ge0$ (resp. $f'(x_0)\le0$).
#
# ---

# %% [markdown]
# <font color=orange> Ilustrujte Dôsledok 1 na konkrétnom príklade funkcie. Všimnite si, že ide o dve implikácie! Ilustrujte a popíšte obe. Na výpočty a vizualizáciu funkcie môžete použiť Sage. </font>

# %% [markdown]
# ---
#
# #### Poznámka 4
#
# Ak funkcia $f$ je rastúca v bode $x_0$ a $f'(x_0)$ existuje, tak $f'(x_0) \geq 0$, ale **nemusí** platiť $f'(x_0) > 0$: $f:\ y = x^3$ je rastúca na $\mathbb{R}$, teda aj v bode $0$, ale $f'(0) = 0$.
#
# ---

# %% [markdown]
# ***
# <a id=extremy></a>
#  # <font color=brown> Hľadanie extrémov funkcie</font>

# %% [markdown]
# V kurze MTIa sme zaviedli pojmy ako lokálne minimum/maximu a globálne minimum/maximum funkcie. Takým bodom hovoríme (lokálne/globálne) extrémy funkcie. Len si pripomeňme, že funkcia $f$ má lokálne minimum v bode $x_0$ svojho definičného oboru ak $f(x_0)$ je menšie alebo rovné ako hodnoty $f(x)$ pre všetky $x$ z nejakého okolia (otvoreného intervalu obsahujúceho $x_0$) bodu $x_0$. Na druhej strane funkcia $f$ má lokálne maximum v bode $x_0$ svojho definičného oboru ak $f(x_0)$ je väčšie alebo rovné ako hodnoty $f(x)$ pre všetky $x$ z nejakého okolia bodu $x_0$. Globálne minimum resp. maximum dostaneme tak, že požiadavku okolia zmeníme, konkrétne aby $f(x_0)\le f(x)$ resp. $f(x_0)\ge f(x)$ pre všetky $x$ z definičného oboru funkcie $f$.
#
# Keď hľadáme extrémy funkcie, častokrát nás zaujímajú také body funkcie, ako sú vyznačené na nasledujúcom grafe funkcie $f(x)=x^3-9x^2-48x+52$. Všimnime si, že v bode $x=-2$ je lokálne maximum funkcie $f$ s hodnotou $f(2)=104$ a v bode $x=8$ je lokálne minimum funkcie $f$ s hodnotou $f(8)=-396$. Tieto dva body majú spoločnú vlastnosť - dotyčnice ku grafu $f$ v týchto bodoch sú rovnobežné s osou $x$, čo znamená, že derivácie v týchto bodoch sú nulové. Také body spolu s bodmi, v ktorých neexistuje derivácia sú dôležité pri hľadaní extrémov funkcie, preto majú aj špecifické pomenovanie - viď Definícia 3.

# %%
# graf + nulova derivacia resp. dotycnica rovnobezna s osou x 
x = var('x') 
f(x) = x^3-9*x^2-48*x+52
kwds = {'fontsize':11} 
plot(f(x), (x, -5, 13), axes_labels=['$x$', '$y$'], axes_labels_size = 1, figsize=5) + plot(f(x), (x, 0.083, 2), axes_labels=['$x$', '$y$'], axes_labels_size = 1) + point((-2, 104), size=20, color='blue') + point((8, -396), size=20, color='blue') + text(r"$f(x)=x^3-9x^2-48x+52$", (8, 100), color='blue',**kwds) + text(r"$-2$", (-2, -20), color='black',**kwds) + text(r"$8$", (8, 20), color='black',**kwds) + line([(8,0),(8,f(8))], linestyle = 'dashed', color = 'black') + line([(0,f(8)),(8,f(8))], linestyle = 'dashed', color = 'black') + line([(-2,0),(-2,f(-2))], linestyle = 'dashed', color = 'black') + line([(0,f(-2)),(-2,f(-2))], linestyle = 'dashed', color = 'black') + line([(-5,f(-2)),(1,f(-2))], linestyle = 'solid', color = 'red') + line([(5,f(8)),(11,f(8))], linestyle = 'solid', color = 'red')
# Out:
# Graphics object consisting of 13 graphics primitives

# %% [markdown]
# ---
#
# ### <font color=red> Definícia 3 </font>
#
# Bod $x_0$ sa nazýva **_stacionárny bod_** funkcie $f$, ak $f'(x_0)=0$. $x_0$ sa nazýva **_kritický bod_** $f$, ak $f'(x_0) = 0$ alebo $f'(x_0)$ neexistuje.
#
# ---

# %% [markdown]
# ---
#
# #### <font color=green> Tvrdenie 4 </font>
#
# Ak má funkcia $f$ v bode $x_0$ lokálne minimum alebo maximum a $f'(x_0)$ existuje, tak $x_0$ je stacionárny bod.
#
# ---

# %% [markdown]
# ---
#
# #### Poznámka 5
#
# - **Funkcia môže teda nadobúdať lokálny extrém (maximum resp. minimum) iba v kritickom bode, t.j. v takom, v ktorom je derivácia nulová alebo neexistuje.** Kandidáti na lokálne extrémy sú teda kritické body. Avšak keď uvažujeme funkciu na uzavretom intervale a hľadáme jej (globálne) extrémy, je potrebné určiť aj funkčné hodnoty v krajných bodoch daného intervalu a porovnať ich s funkčnými hodnotami v kritických bodoch resp. s lokálnymi extrémami (viď Príklad 10 a optimalizačné úlohy ďalej).
#
#
# - Na druhej strane je potrebné si uvedomiť (pozri Príklad 9), že **v kritickom bode môže ale nemusí byť extrém**. Stačí vziať napr. funkciu $f(x)=x^3$ (vykreslite si graf), ktorá má kritický bod $x=0$, avšak pre $x<0$ je táto funkcia rastúca, no taktiež pre $x>0$ je rastúca, preto v bode $x=0$ nie je extrém.
#
# ---

# %% [markdown]
# #### Test na extrémy pomocou prvej derivácie
#
# Predpokladajme, že $x_0$ je stacionárny bod spojitej funkcie $f$, tzn. $f'(x_0)=0$. Ak pri prechode zľava (z ľavého okolia bodu $x_0$) doprava (do pravého okolia bodu $x_0$)
#
# - $f'$ mení znamienko zo záporného na kladné v $x_0$ resp. po prechode cez $x_0$, potom $f$ má lokálne minimum v bode $x_0$;
#
# - $f'$ mení znamienko z kladného na záporné v $x_0$ resp. po prechode cez $x_0$, potom $f$ má lokálne maximum v bode $x_0$.
#
# Popísané situácie sú znázornené na nasledujúcom grafe.

# %%
kwds = {'fontsize':11}
p1 = plot(x^2, (x, -1, 1), axes = False) + point((0,0), size = 40) + text("lokálne minimum", (0, -0.05), color='black',**kwds) + text("$f'(x_0)=0$", (0, -0.12), color='black',**kwds) + text("$[x_0,f(x_0)]$", (0, 0.1), color='blue',**kwds) + text("$f$ klesá", (-1, 0.5), color='black',**kwds) + text("$f'<0$", (-1, 0.43), color='black',**kwds) + text("$f$ rastie", (1, 0.5), color='black',**kwds) + text("$f'>0$", (1, 0.43), color='black',**kwds)
p2 = plot(-x^2, (x, -1, 1), axes = False) + point((0,0), size = 40) + text("lokálne maximum", (0, 0.05), color='black',**kwds) + text("$f'(x_0)=0$", (0, 0.12), color='black',**kwds) + text("$[x_0,f(x_0)]$", (0, -0.1), color='blue',**kwds) + text("$f$ rastie", (-1, -0.53), color='black',**kwds) + text("$f'>0$", (-1, -0.6), color='black',**kwds) + text("$f$ klesá", (1, -0.53), color='black',**kwds) + text("$f'<0$", (1, -0.6), color='black',**kwds)
ga = graphics_array((p1,p2))
show(ga)
# Out:
# Graphics Array of size 1 x 2

# %% [markdown]
# ---
#
# #### <font color=blue> Príklad 8 </font>
#
# Zistite, kde rastie, kde klesá a v ktorých bodoch nadobúda extrémy funkcia $f: y=x\ln x$.
#
# <ins> Riešenie: </ins>
#
# Máme ${\cal{D}}(f)=(0,\infty)$; na tejto množine je $f$ spojitá a $f'(x)=1+\ln x$. Platí
#
# $$
# \begin{aligned}
# &f'(x)>0 \Leftrightarrow 1+\ln x>0 \Leftrightarrow \ln x>-1 \Leftrightarrow x>e^{-1} \Leftrightarrow x\in \bigg(\frac1e,\infty\bigg);\\
# &f'(x)<0 \Leftrightarrow x\in \bigg(0,\frac1e\bigg).
# \end{aligned}
# $$
#
# Teda funkcia $f$ je na $(\frac1e,\infty)$ rastúca, na $(0,\frac1e)$ klesajúca; v bode $x_0=\frac1e$ nadobúda lokálne minimum.

# %%
x = var('x') 
f(x) = x*log(x)
kwds = {'fontsize':11} 
plot(f(x), (x, 0.1, 1.5), axes_labels=['$x$', '$y$'], axes_labels_size = 1, figsize=5) + point((1/e, f(1/e)), size=20, color='blue') + text(r"$f(x)=x\cdot \ln(x)$", (1, 0.4), color='blue',**kwds) + text(r"$1/e$", (1/e, 0.2), color='black',**kwds) + text(r"$[1/e,f(1/e)]$", (1/e, -0.6), color='blue',**kwds) + line([(1/e,0),(1/e,f(1/e))], linestyle = 'dashed', color = 'black') + line([(1/e,f(1/e)),(0,f(1/e))], linestyle = 'dashed', color = 'black')
# Out:
# Graphics object consisting of 7 graphics primitives

# %% [markdown]
# ---

# %% [markdown]
# ---
#
# #### <font color=blue> Príklad 9 </font>
#
# Nájdite lokálne extrémy funkcie $f: y=(x^2-1)^3+1$.
#
# <ins> Riešenie: </ins>
#
# Platí $f'(x)=3\cdot(x^2-1)^2\cdot2x=6x\cdot(x+1)(x-1)$ pre všetky $x\in\mathbb{R}$, teda lokálne extrémy môžu byť len v stacionárnych bodoch, teda v $x_1=-1$, $x_2=0$, $x_3=1$. Pretože $f'(x)>0$ práve vtedy, keď $x>0$ a $f'(x)<0$ práve vtedy, keď $x<0$, je extrém len v bode $x_2$; v bode $x_1$ je $f$ klesajúca a v bode $x_3$ je rastúca.

# %%
x = var('x') 
f(x) = (x^2-1)^3 + 1
kwds = {'fontsize':12} 
plot(f(x), (x, -2, 2), axes_labels=['$x$', '$y$'], axes_labels_size = 1, figsize=5) + point((-1, f(-1)), size=20, color='blue') + point((0, 0), size=20, color='blue') + point((1, f(1)), size=20, color='blue') + text(r"$f(x)=(x^2-1)^3 + 1$", (1, 10), color='blue',**kwds) + line([(1,0),(1,f(1))], linestyle = 'dashed', color = 'black') + line([(-1,0),(-1,f(-1))], linestyle = 'dashed', color = 'black')
# Out:
# Graphics object consisting of 7 graphics primitives

# %% [markdown]
# ---

# %% [markdown]
# ---
#
# #### <font color=green> Tvrdenie 5 (Test na extrémy funkcie pomocou druhej derivácie) </font>
#
# Predpokladajme, že funkcia $f$ je definovaná na nejakom okolí bodu $x_0$ a  $f'(x_0), f''(x_0)$ existujú.
# Ak $f'(x_0)=0$ a $f''(x_0)>0$ (resp. $f''(x_0)<0$), tak $f$ má v bode $x_0$ lokálne minimum (resp. lokálne maximum).
#
# ---

# %%
kwds = {'fontsize':11}
p1 = plot(x^2, (x, -1, 1), axes = False) + point((0,0), size = 40) + text("lokálne minimum", (0, -0.1), color='black',**kwds) + text("$f''>0$ ($f$ konvexná)", (0, 0.5), color='black',**kwds) + text("$[x_0,f(x_0)]$", (0, 0.1), color='blue',**kwds)
p2 = plot(-x^2, (x, -1, 1), axes = False) + point((0,0), size = 40) + text("lokálne maximum", (0, 0.1), color='black',**kwds) + text("$f''<0$ ($f$ konkávna)", (0, -0.5), color='black',**kwds) + text("$[x_0,f(x_0)]$", (0, -0.1), color='blue',**kwds)
ga = graphics_array((p1,p2))
show(ga)
# Out:
# Graphics Array of size 1 x 2

# %% [markdown]
# ---
#
# #### Poznámka 6
#
# - Všimnime si, že Tvrdenie 5 nič nehovorí o situácii, keď $f''(x_0)=0$, v takom prípade toto tvrdenie nevieme využiť.
#
#
# - Ak funkcia je v bode $x_0$ definovaná a spojitá, a naľavo aj napravo od $x_0$ je rastúca (resp. klesajúca) tak v $x_0$ nie je extrém; avšak, ak je funkcia v $x_0$ **nespojitá**, extrém v $x_0$ môže a nemusí nastať:
#
# ![extremy.png](attachment:extremy.png)
# $$\text{Zdroj: Madaras (2019).}$$
#
# ---

# %% [markdown]
# ---
#
# <font color=orange> Aplikujte Tvrdenie 5 na funkcie $f(x)=x^2$, $g(x)=-x^2$, pričom zvoľte bod $x_0=0$ a za okolie tohto bodu vezmite napr. interval $(-1,1)$. Pomôžte si grafmi uvedených funkcií, ktoré sú znázornené pod Tvrdením 5. Postup riadne okomentujte. </font>

# %% [markdown]
# ***
# <a id=konvexnost></a>
#  # <font color=brown> Konvexnosť/konkávnosť funkcie</font>

# %% [markdown]
# ---
#
# ### <font color=red> Definícia 4 </font>
#
# Nech funkcia $f$ je definovaná v okolí bodu $x_0$ a má v bode $x_0$ deriváciu. Potom $f$ sa nazýva **_konvexná v bode_** $x_0$, ak existuje také okolie $U$ bodu $x_0$, že dotyčnica v bode $x_0$ je na $U$ **celá** (okrem bodu $[x_0,f(x_0)]$) **pod** grafom $f$. Podobne, $f$ sa nazýva **_konkávna v bode_** $x_0$, ak dotyčnica v bode $x_0$ je na $U$ **celá** (okrem bodu $[x_0,f(x_0)]$) **nad** grafom $f$.
#
# ---

# %% [markdown]
# $$\text{konkávna funkcia}$$
# ![konkavna.png](attachment:konkavna.png)
#
# $$\text{Zdroj: Madaras (2019).}$$
#
# $$\text{konvexná funkcia}$$
# ![konvexna.png](attachment:konvexna.png)
#
# $$\text{Zdroj: Madaras (2019).}$$

# %% [markdown]
# ---
#
# ### <font color=red> Definícia 5 </font>
#
# Bod $x_0$ sa nazýva **_inflexný bod_** funkcie $f$, ak $f$ je definovaná v okolí bodu $x_0$, existuje $f'(x_0)$ (vlastná alebo nevlastná) a existuje také okolie $U$ bodu $x_0$, že  pre všetky $x\in U$, $x<x_0$ je funkcia $f$ konvexná (resp. konkávna) a pre všetky $x\in U$, $x>x_0$ je funkcia $f$ konkávna (resp. konvexná).
#
# ---

# %% [markdown]
# ---
#
# #### Poznámka 7
#
# - V definícii inflexného bodu sa vyžaduje, aby v bode $x_0$ existovala dotyčnica; teda aj keď sa v bode $x_0$ mení konvexnosť na konkávnosť (resp. naopak), ale ak v bode $x_0$ má funkcia "hrot" (t.j. nemá v ňom dotyčnicu), tak takýto bod **nepovažujeme** za inflexný bod (viď nasledujúci obrázok).
#
# ![nekonvexna2.png](attachment:nekonvexna2.png)
# $$\text{Zdroj: Madaras (2019).}$$
#
# - **Upozornenie !** Nie každý bod $x_0$, v ktorom $f''(x_0)=0$ (alebo $f''$ nie je definovaná) je inflexný bod (podobne ako nie v každom bode, kde $f'=0$ je lokálne maximum alebo minimum). Napr. v prípade $f(x)=x^4$ máme $f''(x)=12x^2$, čiže $f''(0)=0$ ale $f''>0$ pre $x<0$ ale tiež pre $x>0$ a teda nedochádza k zmene konvexnosti (konkávnosti) funkcie v bode $0$ (viď graf), preto bod $0$ nie je inflexný bod. Funkcia $f(x)=x^4$ je konvexná na celom definičnom obore.

# %%
x = var('x') 
f(x) = x^4 
kwds = {'fontsize':12} 
plot(f(x), (x, -2, 2), axes_labels=['$x$', '$y$'], axes_labels_size = 1, figsize=4) + point((0, 0), size=40, color='blue') + text(r"$f(x)=x^4$", (1.2, 10), color='blue',**kwds)
# Out:
# Graphics object consisting of 3 graphics primitives

# %% [markdown]
# ---

# %% [markdown]
# **Príklady inflexných bodov** ($t$ je dotyčnica v $x_0$):
#
# ![inflexie.png](attachment:inflexie.png)
# $$\text{Zdroj: Madaras (2019).}$$
#
# Inflexný bod môže byť aj taký bod, v ktorom je derivácia funkcie **nevlastná**.

# %% [markdown]
# ---
#
# #### <font color=green> Tvrdenie 6 </font>
#
# Predpokladajme, že funkcia $f$ je definovaná na nejakom okolí bodu $x_0$ a že funkcia $f''$ je v bode $x_0$ spojitá.
# Ak $f''(x_0)>0$ (resp. $f''(x_0)<0$), tak $f$ je v bode $x_0$ konvexná (resp. konkávna).
#
# ---

# %% [markdown]
# ---
#
# #### <font color=green> Tvrdenie 7 </font>
#
# Nech funkcia $f$ je definovaná na nejakom okolí bodu $x_0$, $f''(x_0)=0$, $f'''(x_0)\ne0$ a $f'''$ je spojitá v  bode $x_0$. Potom má $f$ v $x_0$ inflexný bod.
#
# ---

# %% [markdown]
# <font color=orange> Ilustrujte Tvrdenie 7 na konkrétnom príklade funkcie. Na výpočty môžete použiť Sage. </font>

# %% [markdown]
# #### Test na inflexný bod pomocou druhej derivácie
#
# Predpokladajme, že funkcia $f$ ma spojitú deriváciu. Ak $f''$ mení znamienko v $x_0$, potom $f$ má inflexný bod v $x_0$ (navyše $f'$ má lokálne minimum alebo lokálne maximum v $x_0$). Opísanú situáciu ilustrujú nasledujúce dva grafy.

# %%
kwds = {'fontsize':11}
f1(x) = -x^3 + 6*x^2 - 12*x + 5 
f2(x) = x^3 - 6*x^2 + 12*x - 5
p1 = plot(f1(x), (x, 1, 3), axes = False) + point((2,f1(2)), size = 20) + text("$[x_0,f(x_0)]$", (2, f1(2)-0.1), color='blue',**kwds) + text("$f''(x_0)=0$", (2, f1(2)+0.1), color='black',**kwds) + text("inflexný bod", (2, f1(2)+0.3), color='black',**kwds) + text("$f$ konvexná", (0.5, f1(1)-0.3), color='black',**kwds) + text("$f''>0$", (0.5, f1(1)-0.5), color='black',**kwds) + text("$f$ konkávna", (2.2, f1(3)+0.3), color='black',**kwds) + text("$f''<0$", (2.2, f1(3)+0.1), color='black',**kwds) 
p2 = plot(f2(x), (x, 1, 3), axes = False) + point((2,f2(2)), size = 20) + text("$[x_0,f(x_0)]$", (2, f2(2)-0.1), color='blue',**kwds) + text("$f''(x_0)=0$", (2, f2(2)+0.1), color='black',**kwds) + text("inflexný bod", (2, f2(2)+0.3), color='black',**kwds) + text("$f$ konkávna", (1.7, f2(1)+0.3), color='black',**kwds) + text("$f''>0$", (1.7, f2(1)+0.1), color='black',**kwds) + text("$f$ konvexná", (3.4, f2(3)-0.3), color='black',**kwds) + text("$f''<0$", (3.4,f2(3)-0.1), color='black',**kwds) 
ga = graphics_array((p1,p2))
show(ga)
# Out:
# Graphics Array of size 1 x 2

# %% [markdown]
# ---
#
# #### <font color=blue> Príklad 10 </font>
#
# Nájdite lokálne extrémy a inflexné body funkcie $g(x)=x\cdot e^{-x}$ pre $x\ge 0$.
#
# <ins> Riešenie: </ins>
#
# Určíme prvú a druhú deriváciu funkcie $g$.

# %%
g(x) = x*e^(-x) # zavedieme funkciu g 
show(g(x)) # zobrazime funkciu g 
deriv1g = diff(g(x),x) # prva derivacia  
show(deriv1g) # zobrazime prvu derivaciu funkcie g 
show(deriv1g.factor()) # upravime prvu derivaciu na tvar, odkial lepsie vidiet kedy je rovna nule 
deriv2g = diff(deriv1g, x) # druha derivacia 
show(deriv2g) # zobrazime druhu derivaciu 
show(deriv2g.factor()) # upravime druhu derivaciu na tvar, odkial lepsie vidiet kedy je rovna nule
# Out:
# x*e^(-x)
# -x*e^(-x) + e^(-x)
# -(x - 1)*e^(-x)
# x*e^(-x) - 2*e^(-x)
# (x - 2)*e^(-x)

# %% [markdown]
# Z uvedených tvarov derivácii je ľahko vidieť, že prvá derivácia je rovná nule pre $x=1$, teda $1$ je kritický bod a dosadením vhodných čísel ľahko overíme, že $g'(x)>0$ pre $x<1$ a $g'(x)<0$ pre $x>1$. Podľa Tvrdenia 2 to znamená, že funkcia $g$ najprv rastie (t.j. $f'>0$) smerom k lokálnemu maximu v bode $1$ s hodnotou $1/e$ a následne klesá (t.j. $f'<0$). Čo sa týka extrémov funkcie, potrebujeme overiť, či extrém nie je v krajnom bode intervalu, čo je v našom prípade bod $0$, keďže uvažujeme $x\ge 0$. Všimnime si, že $g(0)=0$ a $g(x)>0$ pre všetky $x>0$, tým pádom je v bode $0$ lokálne minimum s hodnotou $0$. Navyše $g(x)\rightarrow 0$ keď $x\rightarrow 0$. Podobne z vyjadrenia druhej derivácie je vidieť, že je nulová pre $x=2$ a v bode $2$ je (podľa uvedeného testu na inflexný bod) inflexný bod, lebo $g''(x)<0$ pre $x<2$ a $g''(x)>0$ pre $x>2$.

# %%
eq1 = (deriv1g.factor() == 0) # podmienka pre stacionárny bod 
show(eq1) 
show(solve(eq1, x)) # stacionárny bod ako riešenie predošlej rovnice 
eq2 = (deriv2g.factor() == 0) # podmienka pre inflexný bod 
show(eq2) 
show(solve(eq2, x)) # inflexný bod ako riešenie predošlej rovnice
# Out:
# -(x - 1)*e^(-x) == 0
# [x == 1]
# (x - 2)*e^(-x) == 0
# [x == 2]

# %%
x = var('x') 
f(x) = x*e^(-x) 
kwds1 = {'fontsize':12} 
kwds2 = {'fontsize':8}
plot(f(x), (x, 0, 5), axes_labels=['$x$', '$y$'], axes_labels_size = 1) + point((0, 0), size=40, color='blue') + point((1, f(1)), size=40, color='blue') + point((2, f(2)), size=40, color='blue') + text(r"$f(x)=x\cdot e^{-x}$", (4.8, 0.1), color='blue',**kwds1) + line([(1,f(1)),(1,0)], linestyle = 'dashed', color = 'black') + line([(2,f(2)),(2,0)], linestyle = 'dashed', color = 'black') + text("lokálne minimum", (-0.8, 0.02), color='black',**kwds2) + text("$g$ rastúca, konkávna", (-1.2, 0.2), color='black',**kwds2) + text("stacionárny bod", (1, 0.42), color='black',**kwds2) + text("lokálne maximum", (1, 0.4), color='black',**kwds2)  + text("$g$ klesajúca, konkávna", (2.4, 0.34), color='black',**kwds2) + text("inflexný bod", (2.5, 0.28), color='black',**kwds2) + text("$g$ klesajúca, konvexná", (4, 0.15), color='black',**kwds2)
# Out:
# Graphics object consisting of 14 graphics primitives

# %% [markdown]
# ---

# %% [markdown]
# ***
# <a id=asymptoty></a>
#  # <font color=brown> Asymptoty funkcie </font>

# %% [markdown]
# ---
#
# ### <font color=red> Definícia 6 </font>
#
# Priamka $x = a$ sa nazýva **_asymptota bez smernice_** (niekedy tiež vertikálna asymptota) grafu funkcie $f$, ak $f$ má v bode $a$ nevlastnú limitu sprava alebo zľava.
#
# ---

# %% [markdown]
# ---
#
# #### Poznámka 8
#
# Ak $x=a$ je asymptota bez smernice (prerušovaná čiara resp. priamka na obrázku), tak hodnota $f(a)$ môže alebo nemusí byť definovaná.
#
# ![absky.png](attachment:absky.png)
# $$\text{Zdroj: Madaras (2019).}$$
#
# ---

# %% [markdown]
# ---
#
# ### <font color=red> Definícia 7 </font>
#
# Nech funkcia $f$ je definovaná na intervale $(a,\infty)$ (resp. $-\infty, a)$) pre nejaké $a \in \mathbb{R}$. Priamka $y = kx + q$ sa nazýva **_asymptota so smernicou_** grafu funkcie $f$ pre $x \to \infty$ (resp. $x \to -\infty$), ak $\lim\limits_{x \to \infty} (f(x) - (kx+q)) = 0 $ (resp. $\lim\limits_{x \to -\infty} (f(x) - (kx+q)) = 0 $).
#
# ---

# %% [markdown]
# ---
#
# #### Poznámka 9
#
# * Ak pre definičný obor $f$ platí ${\cal{D}}(f) \subseteq (-\infty,a)$ pre nejaké $a \in \mathbb{R}$, tak funkcia $f$ nemá asymptotu so smernicou pre smer $\infty$, a podobne, ak ${\cal{D}}(f) \subseteq (a,\infty)$, tak $f$ nemá asymptotu so smernicou pre smer $-\infty$.
#
# ![ass.png](attachment:ass.png)
# $$\text{Zdroj: Madaras (2019).}$$
#
#
# * Pokiaľ je smernica $k=0$, tak dostávame priamku v tvare $y=q$, čo je vlastne horizontálna asymptota (rovnobežná s osou $x$).
#
# ---

# %% [markdown]
# **Nasledujúce tvrdenie dobre poslúži pri hľadaní asymptoty so smernicou.**

# %% [markdown]
# ---
#
# #### <font color=green> Tvrdenie 8 </font>
#
# Priamka $y=kx+q$ je asymptotou so smernicou ku funkcii $f$ pre $x\to\infty$ (pre $x\to-\infty$) práve vtedy, keď
#
# $$k=\lim\limits_{x\to\infty}\dfrac{f(x)}x \qquad (k=\lim\limits_{x\to-\infty}\dfrac{f(x)}x)$$
#
# $$q=\lim\limits_{x\to\infty}(f(x)-k\cdot x) \qquad (q=\lim\limits_{x\to-\infty}(f(x)-k\cdot x)).$$
#
# ---

# %% [markdown]
# ---
#
# #### Poznámka 10
#
# Funkcia môže mať dve **rôzne** asymptoty so smernicou, preto je dôležité vypočítať príslušné limity aj pre $x \to -\infty$ (zvlášť v prípade, keď predpis funkcie obsahuje exponenciálne resp. cyklometrické funkcie).
#
# ---

# %% [markdown]
# ***
# <a id=priebeh></a>
#  # <font color=brown> Priebeh funkcie </font>

# %% [markdown]
# Pri zisťovaní priebehu funkcie $f$ zisťujeme nasledujúce skutočnosti:
#
# 1. ${\cal{D}}(f)$, párnosť, nepárnosť, nulové body, priesečník s osou $y$;
#
#
# 2. $f'$;
#
#
# 3. $f''$;
#
#
# 4. stacionárne body a body, v ktorých $f'$ neexistuje;
#
#
# 5. rast, klesanie;
#
#
# 6. lokálne extrémy;
#
#
# 7. body, v ktorých $f''(x)=0$ a body, v ktorých $f''$ neexistuje;
#
#
# 8. konvexnosť, konkávnosť, inflexné body;
#
#
# 9. asymptoty bez smernice;
#
#
# 10. asymptoty so smernicou;
#
#
# 11. skompletizovanie údajov (tabuľka);
#
#
# 12. náčrt grafu.

# %% [markdown]
# ---
#
# #### Poznámka 11
#
# Číslovanie jednotlivých krokov v nasledujúcom príklade je len orientačné a nezodpovedá presne číslovaniu krokov uvedených vyššie! Čísla sú iba orientačné, dôležité je žiaden krok nevynechať!
#
# ---

# %% [markdown]
# ---
#
# #### <font color=blue> Príklad 11 </font>
#
# Vyšetrite priebeh funkcie $f: y=\dfrac{1-2x}{3x^2}$.
#
# <ins> Riešenie: </ins>
#
#
# Ukážeme si, ako by sme takú úlohu riešili "na papieri" a za každým krokom riešenia urobíme aj výpočet v Sage. Pri úlohách tohto typu je výhodné použiť Sage s tým, že jednotlivé kroky riešenia je potrebné vedieť vysvetliť resp. okomentovať (odvolať sa na tvrdenia v predchádzajúcej časti textu a pod.).
#
#
# 1. <ins> Definičný obor </ins>: výraz v menovateli má byť nenulový, teda $3x^2 \neq 0 \Leftrightarrow x \neq 0$, <br/>
# <font color=red> $\mathcal{D}(f) = \mathbb{R} - \{0\}$ </font>.

# %%
# menovatel zlomku musi byt rozny od nuly, preto zistime, kedy sa menovatel rovna nule t.j. vyriesime rovnicu 
# a najdene riesenia vylucime z definicneho oboru funkcie 
x = var('x')
eq1 = (3*x^2 == 0) 
show(eq1)
eq1sol = solve(eq1, x)
show(eq1sol)
# Out:
# 3*x^2 == 0
# [x == 0]

# %% [markdown]
# 2. <ins> Párnosť/nepárnosť </ins>: $\mathbb{D}(f)$ je symetrický vzhľadom na bod $0$; <br/>
# <br/>
# $f(-x) = \dfrac{1-2(-x)}{3(-x)^2} = \dfrac{1+2x}{3x^2}$; <br/>
# <br/>
# pre $x = 1$ je $f(-1) = \dfrac{1+2\cdot 1}{3\cdot 1^2} = \dfrac{3}{3} = 1$; <br/>
# <br/>
# pre $x = 1$ je $f(1) = \dfrac{1-2\cdot 1}{3\cdot 1^2} = -\dfrac{1}{3}$. <br/>
# <br/>
# Teda $f(-1) \neq \pm f(1)$, čiže <font color=red> $f$ nie je ani párna, ani nepárna </font>.

# %%
# zavedieme funkciu f, ktora je v zadani Prikladu 10
f(x) = (1-2*x) / (3*x^2)
show(f(x))
# pozrieme sa na hodnotu f(-x)
show(f(-x))
# vypocitame f(x) a f(-x) pre x=1
show(f(-1))
show(f(+1)) 
# f(-1) je rozne od f(1) 
bool(f(-1) == f(1))
# Out:
# -1/3*(2*x - 1)/x^2
# 1/3*(2*x + 1)/x^2
# 1
# -1/3
# False

# %% [markdown]
# 3. <ins> Nulové body </ins>: $f(x) = 0 \Leftrightarrow \dfrac{1-2x}{3x^2} = 0 \Leftrightarrow 1-2x=0 \Leftrightarrow$ <font color=red> $x = \dfrac{1}{2}$ </font>.

# %%
# najdeme nulove body funkcie - tzn. vyriesime rovnicu, pre ake x je funkcia rovna nule 
eq2 = (f(x) == 0) 
show(eq2)
eq2sol = solve(eq2, x)
show(eq2sol)
# Out:
# -1/3*(2*x - 1)/x^2 == 0
# [x == (1/2)]

# %% [markdown]
# 4. <ins> Priesečník s osou $y$ </ins>: $f(0)$ neexistuje, keďže $0 \not \in \mathcal{D}(f)$ teda priesečník s osou $y$ <font color=red> neexistuje </font>.

# %% [markdown]
# 5. <ins> Prvá derivácia </ins>: $f'(x) = \dfrac{1}{3}\left ( \dfrac{1-2x}{x^2} \right )' = \dfrac{1}{3}\cdot\dfrac{(1-2x)'\cdot x^2 - (1-2x)\cdot(x^2)'}{(x^2)^2} = \dfrac{1}{3}\cdot \dfrac{(-2)x^2 - (1-2x)\cdot(2x)}{x^4} = \dfrac{1}{3}\cdot\dfrac{2x(-x-(1-2x))}{x^4}$ = <font color=red> $\dfrac{2(x-1)}{3x^3}$ </font>.

# %%
# vypocitame prvu derivaciu funkcie f 
der1f = diff(f(x))
show(der1f)
# vyjadrime prvu derivaciu v tvare jedneho zlomku 
der1f = der1f.canonicalize_radical()
show(der1f)
# Out:
# 2/3*(2*x - 1)/x^3 - 2/3/x^2
# 2/3*(x - 1)/x^3

# %% [markdown]
# 6. <ins> Druhá derivácia </ins>: $f''(x) = \dfrac{2}{3} \left ( \dfrac{x-1}{x^3}\right )' = \dfrac{2}{3} \cdot \dfrac{(x-1)'\cdot x^3 - (x-1)\cdot(x^3)'}{(x^3)^2} = \dfrac{2}{3}\cdot\dfrac{1\cdot x^3 - (x-1)\cdot(3x^2)}{x^6} = \dfrac{2}{3}\cdot \dfrac{x^2(x - 3(x-1))}{x^6} =$ <font color=red> $\dfrac{2(3-2x)}{3x^4}$ </font>.

# %%
# vypocitame druhu derivaciu funkcie f 
der2f = diff(der1f(x))
show(der2f)
# vyjadrime druhu derivaciu v tvare jedneho zlomku 
der2f = der2f.canonicalize_radical()
show(der2f)
# Out:
# -2*(x - 1)/x^4 + 2/3/x^3
# -2/3*(2*x - 3)/x^4

# %% [markdown]
# 7. <ins> Stacionárne body </ins>: $f'(x) = 0 \Leftrightarrow \dfrac{2(x-1)}{3x^3} = 0 \Leftrightarrow x-1 = 0 \Leftrightarrow$ <font color=red> $x=1$ </font>.

# %%
# pre najdenie stacionarnych bodov funkcie f zistime, pre ake x je prva derivacia rovna nule 
# t.j. vyriesime rovnicu a najdene riesenia prehlasime za stacionarne body 
eq3 = (der1f == 0) 
show(eq3)
eq3sol = solve(eq3, x)
show(eq3sol)
# Out:
# 2/3*(x - 1)/x^3 == 0
# [x == 1]

# %% [markdown]
# 8. <ins> Rast/klesanie </ins>: body dôležité vzhľadom na prvú deriváciu: $0,1$
# <style type="text/css">
# .tg  {border-collapse:collapse;border-spacing:0;}
# .tg td{border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;
#   overflow:hidden;padding:10px 5px;word-break:normal;}
# .tg th{border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;
#   font-weight:normal;overflow:hidden;padding:10px 5px;word-break:normal;}
# .tg .tg-c3ow{border-color:inherit;text-align:center;vertical-align:top}
# </style>
# <table class="tg">
# <thead>
#   <tr>
#     <th class="tg-c3ow">Interval</th>
#     <th class="tg-c3ow">$(-\infty,0)$</th>
#     <th class="tg-c3ow">$(0,1)$</th>
#     <th class="tg-c3ow">$(1,\infty)$</th>
#   </tr>
# </thead>
# <tbody>
#   <tr>
#     <td class="tg-c3ow">Znamienko $f'$</td>
#     <td class="tg-c3ow">$+$</td>
#     <td class="tg-c3ow">$-$</td>
#     <td class="tg-c3ow">$+$</td>
#   </tr>
# </tbody>
# </table>
# Teda <font color=red> $f$ je klesajúca na $(0,1)$, rastúca na $(-\infty,0),(1,\infty)$ </font>. <br/>
# Využili sme pri tom Tvrdenie 2.

# %%
# overenie znamienok prvej derivacie na prislusnych intervaloch pomocou funkcie bool 
show(bool(der1f(-5)>0)) 
show(bool(der1f(1/2)<0)) 
show(bool(der1f(10)>0))
# Out:
# True
# True
# True

# %% [markdown]
# 9. <ins> Extrémy: </ins>: z tabuľky máme, že v určitom ľavom okolí bodu $1$ funkcia klesá a v pravom okolí $1$ rastie. Teda <font color=red> v bode $1$ je lokálne minimum </font>.

# %% [markdown]
# 10. <ins> Inflexné body </ins>: $f''(x) = 0 \Leftrightarrow \dfrac{2(3-2x)}{3x^4} = 0 \Leftrightarrow 3-2x = 0 \Leftrightarrow$
# <font color=red> $x = \dfrac{3}{2}$ </font>.

# %%
# pre najdenie inflexnych bodov funkcie f zistime, pre ake x je druha derivacia rovna nule 
# t.j. vyriesime rovnicu a najdene riesenia prehlasime za inflexne body (ak sa meni funkcia z konkavnej na kovexnu resp. opacne)
eq4 = (der2f == 0) 
show(eq4)
eq4sol = solve(eq4, x)
show(eq4sol)
# Out:
# -2/3*(2*x - 3)/x^4 == 0
# [x == (3/2)]

# %% [markdown]
# 11. <ins> Konvexnosť/konkávnosť </ins>: body dôležité vzhľadom na druhú deriváciu: $0,\frac{3}{2}$
# <style type="text/css">
# .tg  {border-collapse:collapse;border-spacing:0;}
# .tg td{border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;
#   overflow:hidden;padding:10px 5px;word-break:normal;}
# .tg th{border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;
#   font-weight:normal;overflow:hidden;padding:10px 5px;word-break:normal;}
# .tg .tg-c3ow{border-color:inherit;text-align:center;vertical-align:top}
# </style>
# <table class="tg">
# <thead>
#   <tr>
#     <th class="tg-c3ow">Interval</th>
#     <th class="tg-c3ow">$(-\infty,0)$</th>
#     <th class="tg-c3ow">$\left(0,\frac{3}{2}\right)$</th>
#     <th class="tg-c3ow">$\left(\frac{3}{2},\infty\right)$</th>
#   </tr>
# </thead>
# <tbody>
#   <tr>
#     <td class="tg-c3ow">Znamienko $f''$</td>
#     <td class="tg-c3ow">$+$</td>
#     <td class="tg-c3ow">$+$</td>
#     <td class="tg-c3ow">$-$</td>
#   </tr>
# </tbody>
# </table>
# Teda <font color=red> $f$ je konvexná na $(-\infty,0),\left(0,\frac{3}{2}\right)$, konkávna na $\left(\frac{3}{2},\infty\right)$ </font>. <br/>
# Využili sme Tvrdenie 6.

# %%
# overenie znamienok druhej derivacie na prislusnych intervaloch pomocou funkcie bool 
show(bool(der2f(-5)>0)) 
show(bool(der2f(1/2)>0)) 
show(bool(der2f(10)<0))
# Out:
# True
# True
# True

# %% [markdown]
# 12. <ins> Asymptoty bez smernice </ins>: jediný bod, ktorý prichádza do úvahy, je $x = 0$ (bod nespojitosti); <br/>
# <br/>
# $\lim\limits_{x \to 0+} f(x) = \lim\limits_{x \to 0+} \dfrac{1-2x}{3x^2} = +\infty$ (typ "$\frac{\neq 0}{0}$" s kladným čitateľom a menovateľom v pravom okolí 0); <br/>
# <br/>
# $\lim\limits_{x \to 0-} f(x) = \lim\limits_{x \to 0-} \dfrac{1-2x}{3x^2} = +\infty$ (typ "$\frac{\neq 0}{0}$" s kladným čitateľom a menovateľom v pravom okolí 0). <br/>
# <br/>
# Teda rovnica asymptoty bez smernice je <font color=red> $x=0$ </font>.

# %%
# podla definicie asymptoty bez smernice (ABS) vypocitame pozadovane limity
show(limit(f(x), x=0, dir='+')) 
show(limit(f(x), x=0, dir='-'))
# Out:
# +Infinity
# +Infinity

# %% [markdown]
# 13. <ins> Asymptoty so smernicou </ins>: pre smer $+\infty$: <br/>
# <br/>
# $k = \lim\limits_{x \to \infty} \dfrac{f(x)}{x} = \lim\limits_{x \to \infty} \dfrac{\frac{1-2x}{3x^2}}{x} = \lim\limits_{x \to \infty} \dfrac{1-2x}{3x^3} = 0$ <br/>
# <br/>
# $q = \lim\limits_{x \to \infty} (f(x) - kx) = \lim\limits_{x \to \infty} \left ( \dfrac{1-2x}{3x^2} - 0\cdot x\right ) = 0$ <br/>
# <br/>
# Výsledok limít sa nezmení, ak ich budeme uvažovať pre $x \to -\infty$. <br/>
# <br/>
# Teda rovnica asymptoty so smernicou je <font color=red> $y=0\cdot x + 0  = 0$ </font>.

# %%
# podla definicie asymptoty so smernicou (ASS) vypocitame pozadovane limity 
k = limit(f(x)/x, x=Infinity)
show(k)
q = limit(f(x)-k*x, x=Infinity) 
show(q)
# Out:
# 0
# 0

# %% [markdown]
# 14. <ins> Tabuľka </ins>:
# <style type="text/css">
# .tg  {border-collapse:collapse;border-spacing:0;}
# .tg td{border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;
#   overflow:hidden;padding:10px 5px;word-break:normal;}
# .tg th{border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;
#   font-weight:normal;overflow:hidden;padding:10px 5px;word-break:normal;}
# .tg .tg-baqh{text-align:center;vertical-align:top}
# .tg .tg-amwm{font-weight:bold;text-align:center;vertical-align:top}
# </style>
# <table class="tg">
# <thead>
#   <tr>
#     <th class="tg-amwm">Interval</th>
#     <th class="tg-baqh">$(-\infty,0)$</th>
#     <th class="tg-baqh">$0$</th>
#     <th class="tg-baqh">$(0,1)$</th>
#     <th class="tg-baqh">$1$</th>
#     <th class="tg-baqh">$\left(1,\frac{3}{2}\right)$</th>
#     <th class="tg-baqh">$\frac{3}{2}$</th>
#     <th class="tg-baqh">$\left(\frac{3}{2},\infty\right)$</th>
#   </tr>
# </thead>
# <tbody>
#   <tr>
#     <td class="tg-amwm">Rast/klesanie</td>
#     <td class="tg-baqh">$\nearrow$</td>
#     <td class="tg-baqh">ABS</td>
#     <td class="tg-baqh">$\searrow$</td>
#     <td class="tg-baqh">min.<br>$f(1)=-\frac{1}{3}$</td>
#     <td class="tg-baqh">$\nearrow$</td>
#     <td class="tg-baqh"></td>
#     <td class="tg-baqh">$\nearrow$</td>
#   </tr>
#   <tr>
#     <td class="tg-amwm">Konvex./konkáv.</td>
#     <td class="tg-baqh">$\smile$</td>
#     <td class="tg-baqh"></td>
#     <td class="tg-baqh">$\smile$</td>
#     <td class="tg-baqh"></td>
#     <td class="tg-baqh">$\smile$</td>
#     <td class="tg-baqh">i.b.<br>$f\left(\frac{3}{2}\right)=-\frac{8}{27}$</td>
#     <td class="tg-baqh">$\frown$</td>
#   </tr>
# </tbody>
# </table>
# ABS - asymptota bez smernice, min. - minimum funkcie, i.b. - inflexný bod
#
#
# 15. <ins> Graf </ins>:
#
# ![158a.png](attachment:158a.png)
# $$\text{Zdroj: Madaras (2019).}$$

# %%
x = var('x') 
f(x) = (1-2*x) / (3*x^2)
kwds = {'fontsize':12} 
p1 = plot(f(x), (x, -2, -0.1), axes_labels=['$x$', '$y$'], axes_labels_size = 1) + plot(f(x), (x, 0.083, 2), axes_labels=['$x$', '$y$'], axes_labels_size = 1) + point((1, -1/3), size=20, color='blue') + point((0, 0), size=20, color='blue') + point((3/2, -8/27), size=20, color='blue') + text(r"$f(x)=\dfrac{1-2x}{3x^2}$", (0.6, 20), color='blue',**kwds) + text(r"$[0,0]$", (-0.2, -3), color='blue',**kwds) + text(r"$[1,-1/3]$", (1, 3), color='blue',**kwds) + text(r"$[3/2,-8/27]$", (1.8, 3), color='blue',**kwds) 
show(p1)
# Out:
# Graphics object consisting of 9 graphics primitives

# %%
x = var('x') 
f(x) = (1-2*x) / (3*x^2)
kwds = {'fontsize':12} 
p2 = plot(f(x), (x, 0.4, 2), axes_labels=['$x$', '$y$'], axes_labels_size = 1) + point((1, -1/3), size=20, color='blue') + point((3/2, -8/27), size=20, color='blue') + text(r"$f(x)=\dfrac{1-2x}{3x^2}$", (0.6, 0.6), color='blue',**kwds) + text(r"$[1,-1/3]$", (1, -0.5), color='blue',**kwds) + text(r"$[3/2,-8/27]$", (3/2, -0.45), color='blue',**kwds) 
show(p2)
# Out:
# Graphics object consisting of 6 graphics primitives

# %% [markdown]
# ---

# %% [markdown]
# ---
#
# #### <font color=blue> Príklad 12 </font>
#
# Vyšetrite priebeh funkcie $f: y=x^2-4\sqrt[3]{x^2}$.
#
# <ins> Riešenie: </ins>

# %% [markdown]
# 1. <ins> Definičný obor </ins>: žiadne obmedzujúce podmienky nie sú, teda <font color=red> $\mathcal{D}(f) = \mathbb{R}$ </font>.
#
#
# 2. <ins> Párnosť/nepárnosť </ins>: $\mathcal{D}(f)$ je symetrický vzhľadom na bod 0; <br/>
# $f(-x) = (-x)^2 - 4\sqrt[3]{(-x)^2} = x^2 - 4\sqrt[3]{x^2} = f(x)$. <br/>
# Teda <font color=red> $f$ je párna </font> .

# %%
# zavedieme funkciu f, ktora je v zadani Prikladu 12
f(x) = x^2 - 4*((x^2)^(1/3))
show(f)
# overime parnost t.j., ze f(x) = f(-x)
show(f(x))
show(f(-x))
bool(f(x) == f(-x))
# Out:
# x |--> x^2 - 4*(x^2)^(1/3)
# x^2 - 4*(x^2)^(1/3)
# x^2 - 4*(x^2)^(1/3)
# True

# %% [markdown]
# 3. <ins> Nulové body </ins>: $f(x) = 0 \Leftrightarrow x^2 - 4\sqrt[3]{x^2} = 0 \Leftrightarrow x^2 = 4\sqrt[3]{x^2} \Leftrightarrow x^6 = 64 x^2 \Leftrightarrow x^6 - 64x^2 = 0 \Leftrightarrow x^2(x^2-8)(x^2+8) = 0 \Leftrightarrow x^2(x -\sqrt{8})(x + \sqrt{8})(x^2+8) = 0 \Leftrightarrow$ <font color=red> $x = 0,\pm 2\sqrt{2}$ </font>.

# %%
# najdeme nulove body funkcie - tzn. vyriesime rovnicu, pre ake x je funkcia rovna nule 
eq2 = (f(x) == 0)
show(eq2)
eq2sol = solve(eq2, x, algorithm='sympy')
show(eq2sol)
# Out:
# x^2 - 4*(x^2)^(1/3) == 0
# [x == 0, x == -2*sqrt(2), x == 2*sqrt(2)]

# %% [markdown]
# 4. <ins> Priesečník s osou $y$ </ins>: $[0,f(0)] =$ <font color=red> $[0,0]$ </font>.

# %%
show([0,f(0)])
# Out:
# [0, 0]

# %% [markdown]
# 5. <ins> Prvá derivácia </ins>: $f'(x) = (x^2-4\sqrt[3]{x^2})' = 2x - \left ( 4\cdot x^{\frac{2}{3}}\right )' = 2x - 4\cdot\frac{2}{3}x^{-\frac{1}{3}} =$ <font color=red> $2x -\dfrac{8}{3\sqrt[3]{x}}$ </font>.

# %%
# vypocitame prvu derivaciu funkcie f 
der1f = diff(f(x))
show(der1f)
# iny tvar prvej derivacie 
show(der1f.canonicalize_radical().expand())
# este iny tvar prvej derivacie 
show(der1f.factor())
# Out:
# 2*x - 8/3*x/(x^2)^(2/3)
# 2*x - 8/3/x^(1/3)
# 2/3*x*(3*(x^2)^(2/3) - 4)/(x^2)^(2/3)

# %% [markdown]
# 6. <ins> Druhá derivácia </ins>: $f''(x) =  \left ( 2x -\dfrac{8}{3\sqrt[3]{x}}\right )' = 2 - \left ( \frac{8}{3}x^{-\frac{1}{3}}\right )' = 2 - \frac{8}{3}\left (-\frac{1}{3}x^{-\frac{4}{3}} \right)=$ <font color=red> $2 + \dfrac{8}{9\sqrt[3]{x^4}}$ </font>.

# %%
# vypocitame druhu derivaciu funkcie f 
der2f = diff(der1f(x))
show(der2f)
# upraveny tvar druhej derivacie 
der2f = der2f.factor().canonicalize_radical().expand()
show(der2f)
# Out:
# 32/9*x^2/(x^2)^(5/3) - 8/3/(x^2)^(2/3) + 2
# 8/9/x^(4/3) + 2

# %% [markdown]
# 7. <ins> Stacionárne body </ins>:  $f'(x) = 0 \Leftrightarrow 2x -\dfrac{8}{3\sqrt[3]{x}} = 0 \Leftrightarrow 2x = \dfrac{8}{3\sqrt[3]{x}} \Leftrightarrow 6x\sqrt[3]{x} = 8 \Leftrightarrow 27x^4 = 64 \Leftrightarrow x^4 = \left ( \frac{4}{3}\right )^3 \Leftrightarrow$ <font color=red> $x=\pm \sqrt[4]{\left ( \frac{4}{3}\right )^3}$ </font> <br/>
# <ins> Body, kde $f'$ neexistuje </ins>: vzhľadom na výraz $\sqrt[3]{x}$ v menovateli v $f'$, <font color=red> $f'$ neexistuje pre $x=0$ </font>

# %%
# pre najdenie stacionarnych bodov funkcie f zistime, pre ake x je prva derivacia rovna nule 
# t.j. vyriesime rovnicu a najdene riesenia prehlasime za stacionarne body 
eq3 = (der1f.factor() == 0) 
show(eq3)
eq3sol = solve(eq3, x, algorithm = 'sympy')
show(eq3sol)
# Out:
# 2/3*x*(3*(x^2)^(2/3) - 4)/(x^2)^(2/3) == 0
# [x == -2/3*3^(1/4)*sqrt(2), x == 2/3*3^(1/4)*sqrt(2)]

# %%
show((2/3)*(3^(1/4))*sqrt(2) == (4/3)^(3/4))
show(bool((2/3)*(3^(1/4))*sqrt(2) == (4/3)^(3/4)))
# Out:
# 2/3*3^(1/4)*sqrt(2) == (4/3)^(3/4)
# True

# %% [markdown]
# 8. <ins> Rast/klesanie </ins>: body dôležité vzhľadom na prvú deriváciu: $0,\alpha = -\sqrt[4]{\left ( \frac{4}{3}\right )^3},\beta =\sqrt[4]{\left ( \frac{4}{3}\right )^3}$.
#
# <style type="text/css">
# .tg  {border-collapse:collapse;border-spacing:0;}
# .tg td{border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;
#   overflow:hidden;padding:10px 5px;word-break:normal;}
# .tg th{border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;
#   font-weight:normal;overflow:hidden;padding:10px 5px;word-break:normal;}
# .tg .tg-baqh{text-align:center;vertical-align:top}
# </style>
# <table class="tg">
# <thead>
#   <tr>
#     <th class="tg-baqh">Interval</th>
#     <td class="tg-baqh">$(-\infty,\alpha)$</td>
#     <td class="tg-baqh">$(\alpha,0)$</td>
#     <td class="tg-baqh">$(0,\beta)$</td>
#     <td class="tg-baqh">$(\beta,\infty)$</td>
#   </tr>
# </thead>
# <tbody>
#   <tr>
#     <th class="tg-baqh">Znamienko $f'$</th>
#     <td class="tg-baqh">$-$</td>
#     <td class="tg-baqh">$+$</td>
#     <td class="tg-baqh">$-$</td>
#     <td class="tg-baqh">$+$</td>
#   </tr>
# </tbody>
# </table>
# <br/>
# Teda <font color=red> $f$ je klesajúca na $\left(-\infty,-\sqrt[4]{\left ( \frac{4}{3}\right )^3}\right),\left(0,\sqrt[4]{\left ( \frac{4}{3}\right )^3}\right)$, rastúca na $\left(-\sqrt[4]{\left ( \frac{4}{3}\right )^3},0\right),\left(\sqrt[4]{\left ( \frac{4}{3}\right )^3},\infty\right)$ </font> .
#
#
# 9. <ins> Extrémy </ins>: z tabuľky máme, že v určitom ľavom  okolí bodu $\alpha$ a bodu $\beta$ funkcia klesá a v ich pravom okolí rastie. Súčasne platí, že v $0$ neexistuje prvá derivácia, ale v určitom ľavom okolí $0$ funkcia rastie a v jej pravom okolí klesá. Teda <font color=red> v bodoch $\alpha,\beta$ je lokálne minimum, v bode 0 lokálne maximum </font> .

# %% [markdown]
# 10. <ins> Inflexné body </ins>: $f''(x) = 0 \Leftrightarrow 2 + \dfrac{8}{9\sqrt[3]{x^4}} = 0 \Leftrightarrow \dfrac{8}{9\sqrt[3]{x^4}} = -2$. Táto rovnica nemá riešenie (jej pravá strana je pre všetky $x \neq 0$ kladná). V bode $x = 0$ druhá derivácia neexistuje, avšak funkcia $f$ má v 0 hrot, čiže tento bod nie je inflexný. Teda inflexné body <font color=red> neexistujú </font>.

# %%
# pre najdenie inflexnych bodov funkcie f zistime, pre ake x je druha derivacia rovna nule 
# t.j. vyriesime rovnicu a najdene riesenia prehlasime za inflexne body 
eq4 = (der2f == 0) 
show(eq4)
eq4sol = solve(eq4, x)
show(eq4sol)
# Out:
# 8/9/x^(4/3) + 2 == 0
# []

# %% [markdown]
# 11. <ins> Konvexnosť/konkávnosť </ins>: body dôležité vzhľadom na druhú deriváciu: $0$.
#
# <style type="text/css">
# .tg  {border-collapse:collapse;border-spacing:0;}
# .tg td{border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;
#   overflow:hidden;padding:10px 5px;word-break:normal;}
# .tg th{border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;
#   font-weight:normal;overflow:hidden;padding:10px 5px;word-break:normal;}
# .tg .tg-baqh{text-align:center;vertical-align:top}
# .tg .tg-amwm{font-weight:bold;text-align:center;vertical-align:top}
# </style>
# <table class="tg">
# <thead>
#   <tr>
#     <th class="tg-amwm">Interval</th>
#     <th class="tg-baqh">$(-\infty,0)$</th>
#     <th class="tg-baqh">$(0,\infty)$</th>
#   </tr>
# </thead>
# <tbody>
#   <tr>
#     <td class="tg-amwm">Znamienko $f''$</td>
#     <td class="tg-baqh">+</td>
#     <td class="tg-baqh">+</td>
#   </tr>
# </tbody>
# </table>
#
# Teda <font color=red> $f$ je  konvexná na $(-\infty,0),(0,\infty)$ </font>.
#
#
# 12. <ins> Asymptoty bez smernice </ins>: daná funkcia je spojitá na $\mathbb{R}$ preto <font color=red> asymptoty bez smernice neexistujú </font>.
#
#
# 13. <ins> Asymptoty so smernicou </ins>: pre smer $+\infty$: <br/>
# <br/>
# $k = \lim\limits_{x \to \infty} \dfrac{f(x)}{x} = \lim\limits_{x \to \infty} \dfrac{x^2-4\sqrt[3]{x^2}}{x} = \lim\limits_{x \to \infty} x - \dfrac{4\sqrt[3]{x^2}}{x} = \lim\limits_{x \to \infty} x - 4\sqrt{\dfrac{x^2}{x^3}} = \lim\limits_{x \to \infty} x - 4\lim\limits_{x \to \infty} \sqrt{\dfrac{1}{x}} = +\infty$ <br/>
# <br/>
# Výsledok tejto limity sa nezmení, ak ju budeme uvažovať pre $x \to -\infty$. <br/>
# Teda <font color=red> asymptota so smernicou neexistuje </font>.

# %%
# podla definicie asymptoty so smernicou (ASS) vypocitame pozadovane limity 
k1 = limit(f(x)/x, x=Infinity)
show(k1)
k2 = limit(f(x)/x, x=-Infinity)
show(k2)
# Out:
# +Infinity
# -Infinity

# %% [markdown]
# 14. <ins> Tabuľka </ins>:
#
# <style type="text/css">
# .tg  {border-collapse:collapse;border-spacing:0;}
# .tg td{border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;
#   overflow:hidden;padding:10px 5px;word-break:normal;}
# .tg th{border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;
#   font-weight:normal;overflow:hidden;padding:10px 5px;word-break:normal;}
# .tg .tg-baqh{text-align:center;vertical-align:top}
# .tg .tg-amwm{font-weight:bold;text-align:center;vertical-align:top}
# </style>
# <table class="tg">
# <thead>
#   <tr>
#     <th class="tg-amwm">Interval</th>
#     <td class="tg-baqh">$(-\infty,\alpha)$</td>
#     <td class="tg-baqh">$\alpha$</td>
#     <td class="tg-baqh">$(\alpha,0)$</td>
#     <td class="tg-baqh">$0$</td>
#     <td class="tg-baqh">$(0,\beta)$</td>
#     <td class="tg-baqh">$\beta$</td>
#     <td class="tg-baqh">$(\beta,\infty)$</td>
#   </tr>
# </thead>
# <tbody>
#   <tr>
#     <th class="tg-amwm">Rast/klesanie</th>
#     <td class="tg-baqh">$\searrow$</td>
#     <td class="tg-baqh">min.<br>$f(\alpha)\doteq -3.079$</td>
#     <td class="tg-baqh">$\nearrow$</td>
#     <td class="tg-baqh">max. <br>$f(0)=0$</td>
#     <td class="tg-baqh">$\searrow$</td>
#     <td class="tg-baqh">min. <br>$f(\beta)\doteq -3.079$</td>
#     <td class="tg-baqh">$\nearrow$</td>
#   </tr>
#   <tr>
#     <th class="tg-amwm">Konvex./konkáv.</th>
#     <td class="tg-baqh">$\smile$</td>
#     <td class="tg-baqh"></td>
#     <td class="tg-baqh">$\smile$</td>
#     <td class="tg-baqh"></td>
#     <td class="tg-baqh">$\smile$</td>
#     <td class="tg-baqh"></td>
#     <td class="tg-baqh">$\smile$</td>
#   </tr>
# </tbody>
# </table>
#
#
# 15. <ins> Graf </ins>:
#
# ![171au.png](attachment:171au.png)
# $$\text{Zdroj: Madaras (2019).}$$

# %%
x = var('x') 
f(x) = x^2 - 4*((x^2)^(1/3))
# f2(x) = x^2 - 4*(-x)^(2/3)
kwds = {'fontsize':12} 
# p2 = plot(f2(x), (x, -4, 0), axes_labels=['$x$', '$y$'], axes_labels_size = 1) + plot(f1(x), (x, 0, 4), axes_labels=['$x$', '$y$'], axes_labels_size = 1) + point((-2*sqrt(2), 0), size=20, color='blue') + point((0, 0), size=20, color='blue') + point((2*sqrt(2), 0), size=20, color='blue') + point((-(4/3)^(3/4), 0), size=20, color='blue') + point(((4/3)^(3/4), 0), size=20, color='blue') + line([(-(4/3)^(3/4),0),(-(4/3)^(3/4),f1((4/3)^(3/4)))], color = 'black', linestyle = 'dashed') + line([((4/3)^(3/4),0),((4/3)^(3/4),f1((4/3)^(3/4)))], color = 'black', linestyle = 'dashed') + text(r"$f(x)=x^2-\,4\sqrt[3]{x^2}$", (2.4, 6), color='blue',**kwds) + text(r"$0$", (-0.2, 0.2), color='blue',**kwds) + text(r"$-2\sqrt{2}$", (-2*sqrt(2)+0.3,0.5), color='blue',**kwds) + text(r"$-2\sqrt{2}$", (2*sqrt(2)-0.3,0.5), color='blue',**kwds) + text(r"$-\sqrt[4]{\frac{4}{3}^3}$", (-(4/3)^(3/4), 0.5), color='blue',**kwds) + text(r"$\sqrt[4]{\frac{4}{3}^3}$", ((4/3)^(3/4), 0.5), color='blue',**kwds) 
p2 = plot(f(x), (x, -4, 4), axes_labels=['$x$', '$y$'], axes_labels_size = 1) + point((-2*sqrt(2), 0), size=20, color='blue') + point((0, 0), size=20, color='blue') + point((2*sqrt(2), 0), size=20, color='blue') + point((-(4/3)^(3/4), 0), size=20, color='blue') + point(((4/3)^(3/4), 0), size=20, color='blue') + line([(-(4/3)^(3/4),0),(-(4/3)^(3/4),f1((4/3)^(3/4)))], color = 'black', linestyle = 'dashed') + line([((4/3)^(3/4),0),((4/3)^(3/4),f1((4/3)^(3/4)))], color = 'black', linestyle = 'dashed') + text(r"$f(x)=x^2-\,4\sqrt[3]{x^2}$", (2.4, 6), color='blue',**kwds) + text(r"$0$", (-0.2, 0.2), color='blue',**kwds) + text(r"$-2\sqrt{2}$", (-2*sqrt(2)+0.3,0.5), color='blue',**kwds) + text(r"$-2\sqrt{2}$", (2*sqrt(2)-0.3,0.5), color='blue',**kwds) + text(r"$-\sqrt[4]{\frac{4}{3}^3}$", (-(4/3)^(3/4), 0.5), color='blue',**kwds) + text(r"$\sqrt[4]{\frac{4}{3}^3}$", ((4/3)^(3/4), 0.5), color='blue',**kwds) 
show(p2)
# Out:
# Graphics object consisting of 14 graphics primitives

# %% [markdown]
# ---

# %% [markdown]
# ***
# <a id=optimalizacia></a>
#  # <font color=brown> Optimalizačné úlohy </font>

# %% [markdown]
# ---
#
# #### <font color=blue> Príklad 13 </font>
#
# Keď je šíp vystrelený do vzduchu, jeho dosah, $R$, je definovaný ako vodorovná vzdialenosť od lukostrelca k bodu, kde šíp dopadne na zem. Ak je zem vodorovná a zanedbáme odpor vzduchu, dá sa ukázať, že platí
#
# $$R=\dfrac{v_0^2\sin\,(2\theta)}{g},$$
#
# kde $v_0$ je počiatočná rýchlosť šípu, $g$ je (konštantné) zrýchlenie vďaka gravitácii a $\theta$ je uhol, pod ktorým je šíp vystrelený (viď obrázok), teda $0\le\theta\le\pi/2$. Pod akým uhlom musí byť šíp vystrelený z luku, aby sa maximalizoval dostrel resp. dosah $R$?
#
# ![uloha_sip.png](attachment:uloha_sip.png)
# $$\text{Zdroj: Hallet (2017).}$$
#
# <ins> Riešenie: </ins>
#
# Maximum funkcie $R(\theta)$ je možné nájsť aj bež pužitia kalkulu. Konkrétne funkcia $R$ nadobúda maximum keď $\sin\,(2\theta)=1$ odkiaľ máme riešenie $\theta=\frac{\mathrm{arcsin}\,(1)}{2}=\frac{\pi}{4}$ a hodnota maxima funkcie $R$ v tomto bode je $R(\pi/4)=v_0^2/g$.
#
# Pozrime sa ako je možné túto úlohu vyriešiť pomocou kalkulu. Potrebujeme nájsť globálne maximum funkcie $R$ pre $0\le\theta\le\pi/2$. Nájdeme stacionárne body funkcie $R$, lebo to sú kandidáti na extrémy funkcie. K tomu potrebujeme prvú deriváciu funkcie $R$ podľa premennej $\theta$:
#
# $$R'(\theta)=\dfrac{\mbox{d}R}{\mbox{d}\theta}=2\dfrac{v_0^2\cos\,(2\theta)}{g}.$$
#
# Položíme deriváciu rovnú nule, čím dostávame:
#
# $$2\dfrac{v_0^2\cos\,(2\theta)}{g}=0 \qquad \Leftrightarrow \qquad \cos\,(2\theta)=0 \qquad \Leftrightarrow \qquad 2\theta=\pm\frac{\pi}{2},\pm\frac{3\pi}{2},\pm\frac{5\pi}{2},\ldots,$$
#
# teda $\theta=\frac{\pi}{4}$ je jediný stacionárny bod z intervalu $\langle 0, \pi/2 \rangle$. Dostrel pod uhlom $\theta=\pi/4$ je $R(\pi/4)=v_0^2/g$. <font color=orange> Využite Tvrdenie 5 a pre úplnosť overte, že v bode $\theta=\frac{\pi}{4}$ je naozaj lokálne maximum. </font>  <br/>
# Avšak extrém (minimum alebo maximum) funkcie môže byť i v krajnom bode intervalu, preto musíme preveriť funkčné hodnoty v bodoch $\theta=0$ a $\theta=\pi/2$. Ak budú hodnoty v týchto krajných bodoch menšie ako v bode $\theta=\frac{\pi}{4}$, potom môžeme prehlásiť, že v bode $\theta=\frac{\pi}{4}$ je globálne maximum, keďže iný kandidáti na (lokálne) extrémy už nie sú. Všimnime si, že $R=0$ pre obidva krajné body, čo odpovedá tomu, že šíp je vystrelený horizontálne alebo vertikálne. Tým pádom stacionárny bod $\theta=\frac{\pi}{4}$ je lokálne, no zároveň aj globálne maximum funkcie $R$ na intervale $0\le\theta\le\pi/2$. Inými slovami, šíp doletí najďalej, keď je vystrelený z luku pod uhlom $\pi/4$ resp. $45^\circ$.
#
# ---

# %% [markdown]
# ---
#
# #### <font color=blue> Príklad 14 </font>
#
# Aké by mali byť rozmery hliníkovej plechovky, ktorá pojme $40\,in^3 $ šťavy ($1\,in^3$ t.j. $1$ palec kubický je približne $16.387\,cm^3$), aby spotreba materiálu na jej výrobu bola minimálna? Predpokladajme, že plechovka je valcovitá a je na oboch koncoch zakrytá.
#
# <ins> Riešenie: </ins>
#
# Predtým, ako sa pokúsime vyriešiť problém, je dobré ho najskôr premyslieť. Pretože sa snažíme použiť čo najmenej materiálu, prečo neurobiť plechovku veľmi malú, povedzme, veľkosti arašidu? To nemôžeme, pretože plechovka musí mať predpísaný objem $40\,in^3 $. Ak urobíme plechovku krátku (nízku), aby sme sa pokúsili použiť menej materiálu po stranách, budeme ju musieť urobiť širokú, aby pojala $40\,in^3 $. Pozri obrázok (a) nižšie. <br/>
# Ak sa pokúsime ušetriť materiál tým, že urobíme vrchnú a spodnú časť malú, plechovka musí byť vysoká, aby sa do nej zmestilo $40\,in^3 $ ovocnej šťavy. Takže akékoľvek úspory, ktoré dosiahneme použitím malej hornej a dolnej časti, môžu byť vyvážené výškou strán. Pozri obrázok (b).
#
# ![valce_priklad.png](attachment:valce_priklad.png)
# $$\text{Zdroj: Hallet (2017).}$$
#
# Tabuľka nižšie uvádza výšku $h$ a množstvo materiálu $M$ použitého na plechovku pre niektoré voľby polomeru $r$. Vidíte, že $r$ a $h$ sa menia v opačných smeroch a že v extrémoch (veľmi veľké alebo veľmi malé $r$) sa použije viac materiálu ako v strede. Zdá sa, že polomer, ktorý vyžaduje najmenšie množstvo materiálu $M$, je niekde medzi $1\,in$ a $3\,in$ ($in$ je jednotka dĺžky nazývaná palec, pričom $1\,in$ je cca $2.540\,cm$). Keď uvažujeme o $M$ ako o funkcii polomeru $r$ t.j. $M(r)$, dostaneme graf ako na obrázku dole ($in^2$ je palec štvorcový t.j. jednotka plochy resp. obsahu). Graf ukazuje, že globálne minimum, ktoré chceme, je v stacionárnom bode.
#
# <style type="text/css">
# .tg  {border-collapse:collapse;border-spacing:0;}
# .tg td{border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;
#   overflow:hidden;padding:10px 5px;word-break:normal;}
# .tg th{border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;
#   font-weight:normal;overflow:hidden;padding:10px 5px;word-break:normal;}
# .tg .tg-c3ow{border-color:inherit;text-align:center;vertical-align:top}
# </style>
# <table class="tg">
# <thead>
#   <tr>
#     <th class="tg-c3ow">$r\,(in)$</th>
#     <th class="tg-c3ow">$h\,(in)$</th>
#     <th class="tg-c3ow">$M\,(in^2)$</th>
#   </tr>
# </thead>
# <tbody>
#   <tr>
#     <td class="tg-c3ow">0.2</td>
#     <td class="tg-c3ow">318.31</td>
#     <td class="tg-c3ow">400.25</td>
#   </tr>
#   <tr>
#     <td class="tg-c3ow">1</td>
#     <td class="tg-c3ow">12.73</td>
#     <td class="tg-c3ow">86.28</td>
#   </tr>
#   <tr>
#     <td class="tg-c3ow">2</td>
#     <td class="tg-c3ow">3.18</td>
#     <td class="tg-c3ow">65.13</td>
#   </tr>
#   <tr>
#     <td class="tg-c3ow">3</td>
#     <td class="tg-c3ow">1.41</td>
#     <td class="tg-c3ow">83.22</td>
#   </tr>
#   <tr>
#     <td class="tg-c3ow">4</td>
#     <td class="tg-c3ow">0.80</td>
#     <td class="tg-c3ow">120.53</td>
#   </tr>
#   <tr>
#     <td class="tg-c3ow">10</td>
#     <td class="tg-c3ow">0.13</td>
#     <td class="tg-c3ow">636.32</td>
#   </tr>
# </tbody>
# </table>
#
# ![graf_plechovka_priklad.png](attachment:graf_plechovka_priklad.png)
# $$\text{Zdroj: Hallet (2017).}$$
#
# Tabuľka aj graf boli získané z matematického modelu, ktorý je v tomto prípade vzorcom pre materiál použitý na výrobu plechovky. Nájdenie takéhoto vzorca závisí od poznania geometrie valca, najmä jeho povrchu a objemu. Platí
#
# $$M = \text{ materiál použitý na plechovku } = \text{ materiál použitý na konce (podstava a vrch) } + \text{ materiál použitý na plášť (boky) }, $$
#
# pričom
#
# $$\text{materiál na konce } = 2\cdot \text{ obsah kruhu s polomerom } r = 2\cdot \pi r^2,$$
#
# $$\text{materiál na plášť } = \text{ plocha zakrivenej strany valca s výškou } h \text{ a polomerom } r = 2\pi rh.$$
#
# Máme teda
#
# $$M=2\pi r^2 + 2\pi rh.$$
#
# Avšak výška $h$ nie je nezávislá od polomeru $r$ (pozri úvahu na začiatku príkladu a obrázky (a), (b) ). Totiž ak sa $r$ zväčšuje tak súčasne sa $h$ zmenšuje a vice versa (a naopak). Aby sme našli vzťah medzi $r$ a $h$, využijeme fakt, že objem valca $\pi r^2h$ je podľa zadania príkladu rovný hodnote $40\,in^3$ t.j. $\pi r^2h=40$. Inými slovami,
#
# $$\text{objem plechovky } = \pi r^2h=40, \qquad \text{ odkiaľ } h=\frac{40}{\pi r^2}.$$
#
# Toto vyjadrenie pre výšku valca (plechovky) môžeme dosadiť do predošlého vzťahu, konkrétne
#
# $$\text{materiál na plášť } = 2\pi r h = 2\pi r \frac{40}{\pi r^2}=\frac{80}{r}.$$
#
# Dostali sme tak vzorec pre celkový materiál $M$, potrebný na jednu plechovku s polomerom $r$, ktorá má mať objem $40\,in^3$:
#
# $$M=M(r)=2\pi r^2+\frac{80}{r}.$$
#
# Definičný obor tejto funkcie tvoria všetky $r>0$ lebo polomer plechovky nemôže byť záporný ani nulový. <br/>
# Aby sme našli minimum funkcie $M$, preskúmame najprv stacionárne body ako kandidátov na hľadané (globálne) minimum.
#
# $$M'=\frac{\mbox{d}M}{\mbox{d}r}=4\pi r-\frac{80}{r^2}=0 \text{ v kritickom bode, takže } 4\pi r = \frac{80}{r^2}.$$
#
# Odtiaľ úpravou ďalej dostávame
#
# $$\pi r^3=20, \text{ a teda } r=\left(\frac{20}{\pi}\right)^{1/3}=1.85 \text{ palcov},$$
#
# čo je v zhode s grafom uvedeným vyššie. Po dosadení do vyjadrenia pre výšku $h$ máme
#
# $$h=\frac{40}{\pi r^2}=\frac{40}{\pi(1.85)^2}=3.7 \text{ palcov}.$$
#
# Materiál potrebný pre jednu plechovku je $M=2\pi(1.85)^2+80/1.85=64.7\, in^2$.
#
# <font color=orange> Aplikáciou Tvrdenia 5 pre úplnosť overte, že v bode $r=1.85$ je lokálne minimum. </font>
#
# Aby sme ukázali, že sme naozaj našli globálne (nie iba lokálne) minimum funkcie $M$, pozrime sa na vzorec derivácie $M'$ uvedený vyššie. Pre malé $r$, člen $-80/r^2$ prevažuje (dominuje) a pre veľké $r$ je dominantný člen $4\pi r$. Takže derivácia $M'$ je záporná pre $r<1.85$ a kladná pre $r>1.85$. To znamená (podľa Tvrdenia 2), že funkcia $M$ je klesajúca pre $r<1.85$ a rastúca pre $r>1.85$, preto v bode $r=1.85$ je globálne minimum funkcie $M$.

# %% [markdown]
# ---

# %% [markdown]
# #### Praktické rady pre riešenie optimalizačných úloh pomocou diferenciálneho kalkulu
#
# 1. Uistite sa, že viete, akú veličinu alebo funkciu je potrebné optimalizovať.
#
#
# 2. Ak je to možné, vytvorte niekoľko náčrtov, ktoré ukazujú, ako navzájom sa ovplyvňujúce prvky (veličiny) súvisia. Svoje náčrty jasne označte priradením premenných k veličinám, ktoré sa menia.
#
#
# 3. Pokúste sa získať vyjadrenie (vzorec/predpis) pre funkciu, ktorá sa má optimalizovať vzhľadom na premenné, ktoré ste identifikovali v predchádzajúcom kroku. Ak je to potrebné, z tohto vzorca vylúčte všetky okrem jednej premennej. Určte doménu (napr. interval), v ktorej táto premenná nadobúda svoje hodnoty.
#
#
# 4. Nájdite kritické body a výpočtom funkčných hodnôt v týchto bodoch a koncových bodoch (ak sú relevantné) nájdite globálne maximá a ∕ alebo minimá.

# %% [markdown]
# ***
# <a id=zdroje></a>
#  # <font color=brown> Použité zdroje</font>

# %% [markdown]
# * Boelkins M., Austin D., Schlicker S. (2018). Active Calculus. 978-1085940856.
#
#
# * Goldstein L. J. et al. (2017). Calculus & Its Applications. Pearson Education.
#
#
# * Hartman G. et al. (2018). APEX Calculus. 978-1514225158.
#
#
# * Hallet D. H. et al. (2017). Calculus: Single Variable. Wiley.
#
#
# * Hallet D. H. (2014). Applied Calculus. John Wiley & Sons.
#
#
# * [Prednáška](https://umv.science.upjs.sk/madaras/MZIa/MZIa2011_11.pdf) prof. Madaras.

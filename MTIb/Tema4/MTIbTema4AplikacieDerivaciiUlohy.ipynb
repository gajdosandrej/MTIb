# %% [markdown]
# **Author:** Andrej Gajdoš  <br> *[Faculty of Science](https://www.upjs.sk/en/faculty-of-science/?prefferedLang=EN), P. J. Šafárik University in Košice, Slovakia* <br> email: [andrej.gajdos@upjs.sk](mailto:andrej.gajdos@upjs.sk)
# ***
# **_Tento materiál vznikol za podpory grantu VVGS-2021-1758._**
# ***
#
# **<font size=6 color=green> MTIb: Téma 4 - Aplikácie derivácií funkcií: úlohy </font>**

# %% [markdown]
# ---
#
# **1. Pomocou L'Hospitalovho pravidla (overte, že dané funkcie spĺňajú potrebné predpoklady) vypočítajte limitu funkcie:**
#
# $$\text{a) } \lim\limits_{x\to\infty}\frac{\ln 3x}{x^2};\qquad\qquad \text{b) } \lim\limits_{x\to 0}\left(x^2 \mathrm{e}^{\frac{1}{x^2}}\right);\qquad\qquad \text{c) } \lim\limits_{x\to\frac{\pi}{4}}\frac{\sin x -\cos x}{1-\mathrm{tg}x};$$
#
# $$\text{d) } \lim\limits_{x\to 0}\frac{x 2^x}{2^x -1}; \qquad\qquad \text{e) } \lim\limits_{x\to 1}(2-x)^{\mathrm{tg}\frac{\pi x}{2}};\qquad\qquad \text{f) } \lim\limits_{x\to 1}x^{\frac{1}{1-x}}.$$

# %% [markdown]
# ---
#
# **2. Určte približnú hodnotu čísel $\ln 0.95$ a $\mathrm{arctg}1.07$.**

# %% [markdown]
# ---
#
# **3. Dokážte, že funkcia $h(x)=\arccos\frac{1-x^2}{1+x^2}-2\mathrm{arctg}x$ je konštantná na $(0,\infty)$.**

# %% [markdown]
# ---
#
# **4. Vykreslite/načrtnite graf funkcie $y=f(x)$ ak máte k dispozícii nasledujúce informácie o jej deriváci $f'$:**
#
# * **$f'(x)>0$ pre $x<-1$;**
#
# * **$f'(x)<0$ pre $x>-1$;**
#
# * **$f'(x)=0$ pre $x=-1$.**

# %% [markdown]
# ---
#
# **5. Vyšetrite rastúcosť/klesajúcosť a konvexnosť/konkávnosť funkcie $y=f(x)$, kde:**
#
# $$\text{a) } y=3x^4-4x^3; \qquad\qquad \text{b) } y=\frac{2x}{4-x^2}; \qquad\qquad \text{c) } y=\frac{1+\ln x}{x}; \qquad\qquad \text{d) } y=\frac{x^2-3x}{x+1}.$$

# %% [markdown]
# ---
#
# **6. Určte asymptoty funkcie - bez smernice aj so smernicou (ak existujú) pre funkcie z predchádzajúcej úlohy.**

# %% [markdown]
# ---
#
# **7. Vyšetrite priebeh funkcie $y=f(x)$, ak**
#
# $$\text{a) } y=x^3-3x^2+5; \qquad\qquad \text{b) } y=\frac{x}{x^2+1}; \qquad\qquad \text{c) } y=x+\mathrm{e}^{-x}; \qquad\qquad \text{d) } y=\ln(1+x^2);$$
#
# $$\text{e) } y=\arcsin\frac{2x}{1+x^2}; \qquad\qquad\qquad \text{f) } y=\sqrt{\frac{x-1}{x+1}}; \qquad\qquad\qquad \text{g) } y=\mathrm{e}^x (x-1);$$
#
# $$\text{h) } y=\sqrt[3]{1-x^3}; \qquad\qquad\qquad \text{i) } y=x\cdot\mathrm{arccotg}\frac{1}{x}; \qquad\qquad\qquad \text{j) } y=\mathrm{e}^{-x^2};$$

# %% [markdown]
# **8. Keď sa epidémia šíri populáciou, počet infikovaných ľudí, $I$, je vyjadrený ako funkcia počtu náchylných ľudí, $S$, v tvare**
#
# $$I=I(S)=k\cdot\ln\left(\frac{S}{S_0}\right)-S+S_0+I_0, \qquad k,S_0,I_0>0.$$
#
# **a) Nájdite maximálny počet infikovaných ľudí.**
#
# **b) Konštanta $k$ je charakteristikou konkrétnej choroby; konštanty $S_0$ a $I_0$ sú hodnoty $S$ a $I$ pri začiatku šírenia sa choroby. Čo z toho ovplyvňuje maximálnu možnú hodnotu $I$? Vysvetlite.**
#
# * **Konkrétna choroba, ale nie ako sa začína.**
#
# * **Ako choroba začína, ale nie konkrétna choroba.**
#
# * **Ako konkrétna choroba, tak aj to, ako sa začína.**

# %% [markdown]
# ---
#
# **9. Aby ste čo najlepšie videli Sochu slobody (viď obrázok nižšie), mali by ste byť v pozícii, kde je $\theta$ maximálne. Ak je socha vysoká 92 metrov vrátane podstavca vysokého 46 metrov, ako ďaleko (od sochy) by ste mali byť? (Rada: Nájdite vzorec pre $\theta$ obsahujúci okrem iného aj vašu vzdialenosti od podstavca sochy. Následne využite túto funkciu na maximalizovanie uhla $\theta$ s tým, že $0 \le \theta ≤ \pi/2$).**
#
# ![socha_slobody_priklad.png](attachment:socha_slobody_priklad.png)
# $$\text{Zdroj: Hallet (2017).}$$

# %% [markdown]
# ---
#
# **10. Uveďte príklad funkcie, ktorá má v $x=1$ kritický bod.**

# %% [markdown]
# ---
#
# **11. Uveďte príklad funkcie, u ktorej je globálne minimum rovné globálnemu maximu.**
